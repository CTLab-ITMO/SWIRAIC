# %%
import os

dataset_path = "/kaggle/input/productsdefects-nodefects-01-03-25/productsDefects-noDefects-01-03-25"
train_images_path = os.path.join(dataset_path, "images/train")
train_masks_path = os.path.join(dataset_path, "annotations/train")

dataset_path_test = "/kaggle/input/good-dataset-0-1/good_dataset_0_1"
test_images_path = os.path.join(dataset_path_test, "images/test")
test_masks_path = os.path.join(dataset_path_test, "annotations/test")

print("Train Images:", len(os.listdir(train_images_path)))
print("Train Masks:", len(os.listdir(train_masks_path)))
print("Test Images:", len(os.listdir(test_images_path)))
print("Test Masks:", len(os.listdir(test_masks_path)))

print("\nПримеры файлов (Train Images):", os.listdir(train_images_path)[:5])
print("Примеры файлов (Train Masks):", os.listdir(train_masks_path)[:5])
# Out:
# Train Images: 3517
# Train Masks: 3517
# Test Images: 277
# Test Masks: 277
#
# Примеры файлов (Train Images): ['0006_0084_JPG.rf.a3863aa00c3f3abbdb14840e826ae441.jpg', '023_png.rf.d0418b0479a2cd539d98aa7b59b1a19f.jpg', 'fresh_strawberry_171_jpg.rf.1c96734018e9fff2ed86ff3ac0caf580.jpg', 'fresh_strawberry_122_jpg.rf.38f83af72e476ea9d0df55eb1fc01c37.jpg', '148_png.rf.563e9c619d7ec9a578fa674e4e51c55c.jpg']
# Примеры файлов (Train Masks): ['00480_jpg.rf.ca82249251908e5ab9b5a21e03ac234c.png', '00166_jpg.rf.8fc92688a825a3d4c9d5298c39c5dde1.png', '0008_0014_JPG.rf.1261e130dc9e2252f111752c27e04fbb.png', 'fresh_strawberry_42_jpg.rf.74a81dbf7ac29071798085fe9a2d7ed1.png', '0002_0180_JPG.rf.1671037bf3f4003417ea45a5e4b3291f.png']

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image

# Функция для загрузки и отображения изображения и маски
def visualize_sample(image_path, mask_path):
    if not os.path.exists(image_path):
        print(f"❌ Изображение не найдено: {image_path}")
        return
    if not os.path.exists(mask_path):
        print(f"❌ Маска не найдена: {mask_path}")
        return
    
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    mask = Image.open(mask_path).convert("L")
    mask = np.array(mask)

    
    print(f"✅ Изображение: {image.shape}, Маска: {mask.shape}, dtype: {mask.dtype}")

    
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    ax[0].imshow(image)
    ax[0].set_title("Исходное изображение")
    ax[0].axis("off")

    ax[1].imshow(mask, cmap="gray")
    ax[1].set_title("Маска (размеченные классы)")
    ax[1].axis("off")

    plt.show()


image_files = sorted(os.listdir(train_images_path))
mask_files = sorted(os.listdir(train_masks_path))


sample_image = image_files[0]


sample_mask = os.path.splitext(sample_image)[0] + ".png"


image_path = os.path.join(train_images_path, sample_image)
mask_path = os.path.join(train_masks_path, sample_mask)


visualize_sample(image_path, mask_path)
# Out:
# ✅ Изображение: (234, 326, 3), Маска: (234, 326), dtype: uint8

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T

# Dataset для сегментации с ресайзом
class PlantSegDataset(Dataset):
    def __init__(self, images_dir, masks_dir, transform=None, img_size=512):
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.image_filenames = sorted(os.listdir(images_dir))
        self.transform = transform
        self.img_size = img_size

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        image_filename = self.image_filenames[idx]
        mask_filename = os.path.splitext(image_filename)[0] + ".png"
        image_path = os.path.join(self.images_dir, image_filename)
        mask_path = os.path.join(self.masks_dir, mask_filename)

        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, (self.img_size, self.img_size))  # Ресайз до 512x512
        image = image.astype(np.float32) / 255.0  # Нормализация [0,1]

        #копируем одно и то же изображение в 3 канала)
        image = np.stack([image, image, image], axis=-1)  # [H, W, 3]

        mask = Image.open(mask_path).convert("L")
        mask = mask.resize((self.img_size, self.img_size), Image.NEAREST)  # Ресайз маски (NEAREST для классов)
        mask = np.array(mask, dtype=np.int64)  # Оставляем как int64 (классы)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image, mask = augmented["image"], augmented["mask"]

        image = torch.tensor(image, dtype=torch.float32).permute(2, 0, 1)
        mask = torch.tensor(mask, dtype=torch.long)

        return image, mask

#train
train_dataset = PlantSegDataset(train_images_path, train_masks_path, img_size=512)

sample_img, sample_mask = train_dataset[0]
print(f"Форма изображения: {sample_img.shape}")  # [3, 512, 512]
print(f"Форма маски: {sample_mask.shape}")        # [512, 512]
print(f"Классы в маске: {torch.unique(sample_mask)}")  # Проверяем классы
# Out:
# Форма изображения: torch.Size([3, 512, 512])
# Форма маски: torch.Size([512, 512])
# Классы в маске: tensor([0, 1])

# %%
BATCH_SIZE = 8
NUM_WORKERS = 2

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, drop_last=True)

batch_images, batch_masks = next(iter(train_loader))
print(f"Размер batch изображений: {batch_images.shape}")  # [B, 3, 512, 512]
print(f"Размер batch масок: {batch_masks.shape}")        # [B, 512, 512]
# Out:
# Размер batch изображений: torch.Size([8, 3, 512, 512])
# Размер batch масок: torch.Size([8, 512, 512])

# %%
mask_files = sorted(os.listdir(train_masks_path))[:1]

for mask_file in mask_files:
    mask_path = os.path.join(train_masks_path, mask_file)
    mask = Image.open(mask_path)
    mask_array = np.array(mask)

    print(f"Маска: {mask_file} → Уникальные классы: {np.unique(mask_array)}")
# Out:
# Маска: 00001_jpg.rf.664f3ba4acb20b99bf3807287487a616.png → Уникальные классы: [0 1]

# %%
mask_files = sorted(os.listdir(train_masks_path))

all_classes = set()

for mask_file in mask_files:
    mask_path = os.path.join(train_masks_path, mask_file)
    mask = Image.open(mask_path)
    mask_array = np.array(mask)
    
    unique_classes = np.unique(mask_array)
    all_classes.update(unique_classes)

print(f"Общее количество уникальных классов: {len(all_classes)}")
print(f"Уникальные классы: {sorted(all_classes)}")
# Out:
# Общее количество уникальных классов: 2
# Уникальные классы: [0, 1]

# %%
print(len(all_classes))
# Out:
# 2

# %%
import torch.nn as nn
import torchvision.models.segmentation as segmentation
from torch.optim import Adam

model = segmentation.deeplabv3_resnet101(pretrained=True)
num_classes = 2  # Включая класс фона
model.classifier[4] = nn.Conv2d(256, num_classes, kernel_size=(1, 1), stride=(1, 1))
model.aux_classifier[4] = nn.Conv2d(256, num_classes, kernel_size=(1, 1), stride=(1, 1))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# 100%|██████████| 233M/233M [00:01<00:00, 232MB/s]
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# Замораживаем все слои модели, кроме классификаторов
for param in model.parameters():
    param.requires_grad = False

# Размораживаем последний блок и классификаторы (включая aux_classifier)
for param in model.classifier.parameters():
    param.requires_grad = True

# Размораживаем aux_classifier
for param in model.aux_classifier.parameters():
    param.requires_grad = True

# Заменяем последний слой на соответствующее количество классов
num_classes = 2  # Включая класс фона
model.classifier[4] = nn.Conv2d(256, num_classes, kernel_size=(1, 1), stride=(1, 1))
model.aux_classifier[4] = nn.Conv2d(256, num_classes, kernel_size=(1, 1), stride=(1, 1))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"Обучается: {name}")
    else:
        print(f"Заморожено: {name}")
# Out:
# Заморожено: backbone.conv1.weight
# Заморожено: backbone.bn1.weight
# Заморожено: backbone.bn1.bias
# Заморожено: backbone.layer1.0.conv1.weight
# Заморожено: backbone.layer1.0.bn1.weight
# Заморожено: backbone.layer1.0.bn1.bias
# Заморожено: backbone.layer1.0.conv2.weight
# Заморожено: backbone.layer1.0.bn2.weight
# Заморожено: backbone.layer1.0.bn2.bias
# Заморожено: backbone.layer1.0.conv3.weight
# Заморожено: backbone.layer1.0.bn3.weight
# Заморожено: backbone.layer1.0.bn3.bias
# Заморожено: backbone.layer1.0.downsample.0.weight
# Заморожено: backbone.layer1.0.downsample.1.weight
# Заморожено: backbone.layer1.0.downsample.1.bias
# Заморожено: backbone.layer1.1.conv1.weight
# Заморожено: backbone.layer1.1.bn1.weight
# Заморожено: backbone.layer1.1.bn1.bias
# Заморожено: backbone.layer1.1.conv2.weight
# Заморожено: backbone.layer1.1.bn2.weight
# Заморожено: backbone.layer1.1.bn2.bias
# Заморожено: backbone.layer1.1.conv3.weight
# Заморожено: backbone.layer1.1.bn3.weight
# Заморожено: backbone.layer1.1.bn3.bias
# Заморожено: backbone.layer1.2.conv1.weight
# Заморожено: backbone.layer1.2.bn1.weight
# Заморожено: backbone.layer1.2.bn1.bias
# Заморожено: backbone.layer1.2.conv2.weight
# Заморожено: backbone.layer1.2.bn2.weight
# Заморожено: backbone.layer1.2.bn2.bias
# Заморожено: backbone.layer1.2.conv3.weight
# Заморожено: backbone.layer1.2.bn3.weight
# Заморожено: backbone.layer1.2.bn3.bias
# Заморожено: backbone.layer2.0.conv1.weight
# Заморожено: backbone.layer2.0.bn1.weight
# Заморожено: backbone.layer2.0.bn1.bias
# Заморожено: backbone.layer2.0.conv2.weight
# Заморожено: backbone.layer2.0.bn2.weight
# Заморожено: backbone.layer2.0.bn2.bias
# Заморожено: backbone.layer2.0.conv3.weight
# Заморожено: backbone.layer2.0.bn3.weight
# Заморожено: backbone.layer2.0.bn3.bias
# Заморожено: backbone.layer2.0.downsample.0.weight
# Заморожено: backbone.layer2.0.downsample.1.weight
# Заморожено: backbone.layer2.0.downsample.1.bias
# Заморожено: backbone.layer2.1.conv1.weight
# Заморожено: backbone.layer2.1.bn1.weight
# Заморожено: backbone.layer2.1.bn1.bias
# Заморожено: backbone.layer2.1.conv2.weight
# Заморожено: backbone.layer2.1.bn2.weight
# Заморожено: backbone.layer2.1.bn2.bias
# Заморожено: backbone.layer2.1.conv3.weight
# Заморожено: backbone.layer2.1.bn3.weight
# Заморожено: backbone.layer2.1.bn3.bias
# Заморожено: backbone.layer2.2.conv1.weight
# Заморожено: backbone.layer2.2.bn1.weight
# Заморожено: backbone.layer2.2.bn1.bias
# Заморожено: backbone.layer2.2.conv2.weight
# Заморожено: backbone.layer2.2.bn2.weight
# Заморожено: backbone.layer2.2.bn2.bias
# Заморожено: backbone.layer2.2.conv3.weight
# Заморожено: backbone.layer2.2.bn3.weight
# Заморожено: backbone.layer2.2.bn3.bias
# Заморожено: backbone.layer2.3.conv1.weight
# Заморожено: backbone.layer2.3.bn1.weight
# Заморожено: backbone.layer2.3.bn1.bias
# Заморожено: backbone.layer2.3.conv2.weight
# Заморожено: backbone.layer2.3.bn2.weight
# Заморожено: backbone.layer2.3.bn2.bias
# Заморожено: backbone.layer2.3.conv3.weight
# Заморожено: backbone.layer2.3.bn3.weight
# Заморожено: backbone.layer2.3.bn3.bias
# Заморожено: backbone.layer3.0.conv1.weight
# Заморожено: backbone.layer3.0.bn1.weight
# Заморожено: backbone.layer3.0.bn1.bias
# Заморожено: backbone.layer3.0.conv2.weight
# Заморожено: backbone.layer3.0.bn2.weight
# Заморожено: backbone.layer3.0.bn2.bias
# Заморожено: backbone.layer3.0.conv3.weight
# Заморожено: backbone.layer3.0.bn3.weight
# Заморожено: backbone.layer3.0.bn3.bias
# Заморожено: backbone.layer3.0.downsample.0.weight
# Заморожено: backbone.layer3.0.downsample.1.weight
# Заморожено: backbone.layer3.0.downsample.1.bias
# Заморожено: backbone.layer3.1.conv1.weight
# Заморожено: backbone.layer3.1.bn1.weight
# Заморожено: backbone.layer3.1.bn1.bias
# Заморожено: backbone.layer3.1.conv2.weight
# Заморожено: backbone.layer3.1.bn2.weight
# Заморожено: backbone.layer3.1.bn2.bias
# Заморожено: backbone.layer3.1.conv3.weight
# Заморожено: backbone.layer3.1.bn3.weight
# Заморожено: backbone.layer3.1.bn3.bias
# Заморожено: backbone.layer3.2.conv1.weight
# Заморожено: backbone.layer3.2.bn1.weight
# Заморожено: backbone.layer3.2.bn1.bias
# Заморожено: backbone.layer3.2.conv2.weight
# Заморожено: backbone.layer3.2.bn2.weight
# Заморожено: backbone.layer3.2.bn2.bias
# Заморожено: backbone.layer3.2.conv3.weight
# Заморожено: backbone.layer3.2.bn3.weight
# Заморожено: backbone.layer3.2.bn3.bias
# Заморожено: backbone.layer3.3.conv1.weight
# Заморожено: backbone.layer3.3.bn1.weight
# Заморожено: backbone.layer3.3.bn1.bias
# Заморожено: backbone.layer3.3.conv2.weight
# Заморожено: backbone.layer3.3.bn2.weight
# Заморожено: backbone.layer3.3.bn2.bias
# Заморожено: backbone.layer3.3.conv3.weight
# Заморожено: backbone.layer3.3.bn3.weight
# Заморожено: backbone.layer3.3.bn3.bias
# Заморожено: backbone.layer3.4.conv1.weight
# Заморожено: backbone.layer3.4.bn1.weight
# Заморожено: backbone.layer3.4.bn1.bias
# Заморожено: backbone.layer3.4.conv2.weight
# Заморожено: backbone.layer3.4.bn2.weight
# Заморожено: backbone.layer3.4.bn2.bias
# Заморожено: backbone.layer3.4.conv3.weight
# Заморожено: backbone.layer3.4.bn3.weight
# Заморожено: backbone.layer3.4.bn3.bias
# Заморожено: backbone.layer3.5.conv1.weight
# Заморожено: backbone.layer3.5.bn1.weight
# Заморожено: backbone.layer3.5.bn1.bias
# Заморожено: backbone.layer3.5.conv2.weight
# Заморожено: backbone.layer3.5.bn2.weight
# Заморожено: backbone.layer3.5.bn2.bias
# Заморожено: backbone.layer3.5.conv3.weight
# Заморожено: backbone.layer3.5.bn3.weight
# Заморожено: backbone.layer3.5.bn3.bias
# Заморожено: backbone.layer3.6.conv1.weight
# Заморожено: backbone.layer3.6.bn1.weight
# Заморожено: backbone.layer3.6.bn1.bias
# Заморожено: backbone.layer3.6.conv2.weight
# Заморожено: backbone.layer3.6.bn2.weight
# Заморожено: backbone.layer3.6.bn2.bias
# Заморожено: backbone.layer3.6.conv3.weight
# Заморожено: backbone.layer3.6.bn3.weight
# Заморожено: backbone.layer3.6.bn3.bias
# Заморожено: backbone.layer3.7.conv1.weight
# Заморожено: backbone.layer3.7.bn1.weight
# Заморожено: backbone.layer3.7.bn1.bias
# Заморожено: backbone.layer3.7.conv2.weight
# Заморожено: backbone.layer3.7.bn2.weight
# Заморожено: backbone.layer3.7.bn2.bias
# Заморожено: backbone.layer3.7.conv3.weight
# Заморожено: backbone.layer3.7.bn3.weight
# Заморожено: backbone.layer3.7.bn3.bias
# Заморожено: backbone.layer3.8.conv1.weight
# Заморожено: backbone.layer3.8.bn1.weight
# Заморожено: backbone.layer3.8.bn1.bias
# Заморожено: backbone.layer3.8.conv2.weight
# Заморожено: backbone.layer3.8.bn2.weight
# Заморожено: backbone.layer3.8.bn2.bias
# Заморожено: backbone.layer3.8.conv3.weight
# Заморожено: backbone.layer3.8.bn3.weight
# Заморожено: backbone.layer3.8.bn3.bias
# Заморожено: backbone.layer3.9.conv1.weight
# Заморожено: backbone.layer3.9.bn1.weight
# Заморожено: backbone.layer3.9.bn1.bias
# Заморожено: backbone.layer3.9.conv2.weight
# Заморожено: backbone.layer3.9.bn2.weight
# Заморожено: backbone.layer3.9.bn2.bias
# Заморожено: backbone.layer3.9.conv3.weight
# Заморожено: backbone.layer3.9.bn3.weight
# Заморожено: backbone.layer3.9.bn3.bias
# Заморожено: backbone.layer3.10.conv1.weight
# Заморожено: backbone.layer3.10.bn1.weight
# Заморожено: backbone.layer3.10.bn1.bias
# Заморожено: backbone.layer3.10.conv2.weight
# Заморожено: backbone.layer3.10.bn2.weight
# Заморожено: backbone.layer3.10.bn2.bias
# Заморожено: backbone.layer3.10.conv3.weight
# Заморожено: backbone.layer3.10.bn3.weight
# Заморожено: backbone.layer3.10.bn3.bias
# Заморожено: backbone.layer3.11.conv1.weight
# Заморожено: backbone.layer3.11.bn1.weight
# Заморожено: backbone.layer3.11.bn1.bias
# Заморожено: backbone.layer3.11.conv2.weight
# Заморожено: backbone.layer3.11.bn2.weight
# Заморожено: backbone.layer3.11.bn2.bias
# Заморожено: backbone.layer3.11.conv3.weight
# Заморожено: backbone.layer3.11.bn3.weight
# Заморожено: backbone.layer3.11.bn3.bias
# Заморожено: backbone.layer3.12.conv1.weight
# Заморожено: backbone.layer3.12.bn1.weight
# Заморожено: backbone.layer3.12.bn1.bias
# Заморожено: backbone.layer3.12.conv2.weight
# Заморожено: backbone.layer3.12.bn2.weight
# Заморожено: backbone.layer3.12.bn2.bias
# Заморожено: backbone.layer3.12.conv3.weight
# Заморожено: backbone.layer3.12.bn3.weight
# Заморожено: backbone.layer3.12.bn3.bias
# Заморожено: backbone.layer3.13.conv1.weight
# Заморожено: backbone.layer3.13.bn1.weight
# Заморожено: backbone.layer3.13.bn1.bias
# Заморожено: backbone.layer3.13.conv2.weight
# Заморожено: backbone.layer3.13.bn2.weight
# Заморожено: backbone.layer3.13.bn2.bias
# Заморожено: backbone.layer3.13.conv3.weight
# Заморожено: backbone.layer3.13.bn3.weight
# Заморожено: backbone.layer3.13.bn3.bias
# Заморожено: backbone.layer3.14.conv1.weight
# Заморожено: backbone.layer3.14.bn1.weight
# Заморожено: backbone.layer3.14.bn1.bias
# Заморожено: backbone.layer3.14.conv2.weight
# Заморожено: backbone.layer3.14.bn2.weight
# Заморожено: backbone.layer3.14.bn2.bias
# Заморожено: backbone.layer3.14.conv3.weight
# Заморожено: backbone.layer3.14.bn3.weight
# Заморожено: backbone.layer3.14.bn3.bias
# Заморожено: backbone.layer3.15.conv1.weight
# Заморожено: backbone.layer3.15.bn1.weight
# Заморожено: backbone.layer3.15.bn1.bias
# Заморожено: backbone.layer3.15.conv2.weight
# Заморожено: backbone.layer3.15.bn2.weight
# Заморожено: backbone.layer3.15.bn2.bias
# Заморожено: backbone.layer3.15.conv3.weight
# Заморожено: backbone.layer3.15.bn3.weight
# Заморожено: backbone.layer3.15.bn3.bias
# Заморожено: backbone.layer3.16.conv1.weight
# Заморожено: backbone.layer3.16.bn1.weight
# Заморожено: backbone.layer3.16.bn1.bias
# Заморожено: backbone.layer3.16.conv2.weight
# Заморожено: backbone.layer3.16.bn2.weight
# Заморожено: backbone.layer3.16.bn2.bias
# Заморожено: backbone.layer3.16.conv3.weight
# Заморожено: backbone.layer3.16.bn3.weight
# Заморожено: backbone.layer3.16.bn3.bias
# Заморожено: backbone.layer3.17.conv1.weight
# Заморожено: backbone.layer3.17.bn1.weight
# Заморожено: backbone.layer3.17.bn1.bias
# Заморожено: backbone.layer3.17.conv2.weight
# Заморожено: backbone.layer3.17.bn2.weight
# Заморожено: backbone.layer3.17.bn2.bias
# Заморожено: backbone.layer3.17.conv3.weight
# Заморожено: backbone.layer3.17.bn3.weight
# Заморожено: backbone.layer3.17.bn3.bias
# Заморожено: backbone.layer3.18.conv1.weight
# Заморожено: backbone.layer3.18.bn1.weight
# Заморожено: backbone.layer3.18.bn1.bias
# Заморожено: backbone.layer3.18.conv2.weight
# Заморожено: backbone.layer3.18.bn2.weight
# Заморожено: backbone.layer3.18.bn2.bias
# Заморожено: backbone.layer3.18.conv3.weight
# Заморожено: backbone.layer3.18.bn3.weight
# Заморожено: backbone.layer3.18.bn3.bias
# Заморожено: backbone.layer3.19.conv1.weight
# Заморожено: backbone.layer3.19.bn1.weight
# Заморожено: backbone.layer3.19.bn1.bias
# Заморожено: backbone.layer3.19.conv2.weight
# Заморожено: backbone.layer3.19.bn2.weight
# Заморожено: backbone.layer3.19.bn2.bias
# Заморожено: backbone.layer3.19.conv3.weight
# Заморожено: backbone.layer3.19.bn3.weight
# Заморожено: backbone.layer3.19.bn3.bias
# Заморожено: backbone.layer3.20.conv1.weight
# Заморожено: backbone.layer3.20.bn1.weight
# Заморожено: backbone.layer3.20.bn1.bias
# Заморожено: backbone.layer3.20.conv2.weight
# Заморожено: backbone.layer3.20.bn2.weight
# Заморожено: backbone.layer3.20.bn2.bias
# Заморожено: backbone.layer3.20.conv3.weight
# Заморожено: backbone.layer3.20.bn3.weight
# Заморожено: backbone.layer3.20.bn3.bias
# Заморожено: backbone.layer3.21.conv1.weight
# Заморожено: backbone.layer3.21.bn1.weight
# Заморожено: backbone.layer3.21.bn1.bias
# Заморожено: backbone.layer3.21.conv2.weight
# Заморожено: backbone.layer3.21.bn2.weight
# Заморожено: backbone.layer3.21.bn2.bias
# Заморожено: backbone.layer3.21.conv3.weight
# Заморожено: backbone.layer3.21.bn3.weight
# Заморожено: backbone.layer3.21.bn3.bias
# Заморожено: backbone.layer3.22.conv1.weight
# Заморожено: backbone.layer3.22.bn1.weight
# Заморожено: backbone.layer3.22.bn1.bias
# Заморожено: backbone.layer3.22.conv2.weight
# Заморожено: backbone.layer3.22.bn2.weight
# Заморожено: backbone.layer3.22.bn2.bias
# Заморожено: backbone.layer3.22.conv3.weight
# Заморожено: backbone.layer3.22.bn3.weight
# Заморожено: backbone.layer3.22.bn3.bias
# Заморожено: backbone.layer4.0.conv1.weight
# Заморожено: backbone.layer4.0.bn1.weight
# Заморожено: backbone.layer4.0.bn1.bias
# Заморожено: backbone.layer4.0.conv2.weight
# Заморожено: backbone.layer4.0.bn2.weight
# Заморожено: backbone.layer4.0.bn2.bias
# Заморожено: backbone.layer4.0.conv3.weight
# Заморожено: backbone.layer4.0.bn3.weight
# Заморожено: backbone.layer4.0.bn3.bias
# Заморожено: backbone.layer4.0.downsample.0.weight
# Заморожено: backbone.layer4.0.downsample.1.weight
# Заморожено: backbone.layer4.0.downsample.1.bias
# Заморожено: backbone.layer4.1.conv1.weight
# Заморожено: backbone.layer4.1.bn1.weight
# Заморожено: backbone.layer4.1.bn1.bias
# Заморожено: backbone.layer4.1.conv2.weight
# Заморожено: backbone.layer4.1.bn2.weight
# Заморожено: backbone.layer4.1.bn2.bias
# Заморожено: backbone.layer4.1.conv3.weight
# Заморожено: backbone.layer4.1.bn3.weight
# Заморожено: backbone.layer4.1.bn3.bias
# Заморожено: backbone.layer4.2.conv1.weight
# Заморожено: backbone.layer4.2.bn1.weight
# Заморожено: backbone.layer4.2.bn1.bias
# Заморожено: backbone.layer4.2.conv2.weight
# Заморожено: backbone.layer4.2.bn2.weight
# Заморожено: backbone.layer4.2.bn2.bias
# Заморожено: backbone.layer4.2.conv3.weight
# Заморожено: backbone.layer4.2.bn3.weight
# Заморожено: backbone.layer4.2.bn3.bias
# Обучается: classifier.0.convs.0.0.weight
# Обучается: classifier.0.convs.0.1.weight
# Обучается: classifier.0.convs.0.1.bias
# Обучается: classifier.0.convs.1.0.weight
# Обучается: classifier.0.convs.1.1.weight
# Обучается: classifier.0.convs.1.1.bias
# Обучается: classifier.0.convs.2.0.weight
# Обучается: classifier.0.convs.2.1.weight
# Обучается: classifier.0.convs.2.1.bias
# Обучается: classifier.0.convs.3.0.weight
# Обучается: classifier.0.convs.3.1.weight
# Обучается: classifier.0.convs.3.1.bias
# Обучается: classifier.0.convs.4.1.weight
# Обучается: classifier.0.convs.4.2.weight
# Обучается: classifier.0.convs.4.2.bias
# Обучается: classifier.0.project.0.weight
# Обучается: classifier.0.project.1.weight
# Обучается: classifier.0.project.1.bias
# Обучается: classifier.1.weight
# Обучается: classifier.2.weight
# Обучается: classifier.2.bias
# Обучается: classifier.4.weight
# Обучается: classifier.4.bias
# Обучается: aux_classifier.0.weight
# Обучается: aux_classifier.1.weight
# Обучается: aux_classifier.1.bias
# Обучается: aux_classifier.4.weight
# Обучается: aux_classifier.4.bias

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
import torchvision
from torchvision import transforms
from sklearn.metrics import confusion_matrix

for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"{name} разморожен")

train_dataset = PlantSegDataset(train_images_path, train_masks_path, img_size=512)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4, drop_last=True)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

criterion = nn.CrossEntropyLoss()

# Функция для расчета IoU
def calculate_iou(preds, labels, num_classes):
    """
    Функция для расчета IoU для всех классов.
    """
    preds = preds.argmax(dim=1)
    iou_per_class = []
    for i in range(num_classes):
        intersection = ((preds == i) & (labels == i)).sum().item()
        union = ((preds == i) | (labels == i)).sum().item()
        iou = intersection / union if union != 0 else float('nan')
        iou_per_class.append(iou)
    return iou_per_class


epochs = 10
all_losses = []  # Список для хранения потерь
all_ious = []  # Список для хранения IoU на каждой эпохе

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    iou_list = []  # Список для IoU на одной эпохе
    
    for batch_idx, (images, masks) in enumerate(train_loader):
        images, masks = images.to(device), masks.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        output = outputs['out']

        loss = criterion(output, masks)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Вычисляем IoU для текущего батча
        iou_batch = calculate_iou(output, masks, num_classes=2)
        iou_list.append(iou_batch)

        # Выводим потери на каждой 10-й итерации
        if batch_idx % 10 == 0:
            print(f"Эпоха {epoch+1}/{epochs}, Итерация {batch_idx}/{len(train_loader)}, Потери: {running_loss/(batch_idx+1)}")


    avg_loss = running_loss / len(train_loader)
    avg_iou = np.nanmean(iou_list)
    all_losses.append(avg_loss)
    all_ious.append(avg_iou)

    print(f"Эпоха {epoch+1}/{epochs}, Средние потери: {avg_loss:.4f}, Средний IoU: {avg_iou:.4f}")


torch.save(model.state_dict(), "deeplabv3_resnet101-good-dataset-0-1(+no-defects)-finetuned.pth")


plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(range(epochs), all_losses, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()


plt.subplot(1, 2, 2)
plt.plot(range(epochs), all_ious, label='IoU', color='orange')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.title('Mean IoU per Epoch')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# classifier.0.convs.0.0.weight разморожен
# classifier.0.convs.0.1.weight разморожен
# classifier.0.convs.0.1.bias разморожен
# classifier.0.convs.1.0.weight разморожен
# classifier.0.convs.1.1.weight разморожен
# classifier.0.convs.1.1.bias разморожен
# classifier.0.convs.2.0.weight разморожен
# classifier.0.convs.2.1.weight разморожен
# classifier.0.convs.2.1.bias разморожен
# classifier.0.convs.3.0.weight разморожен
# classifier.0.convs.3.1.weight разморожен
# classifier.0.convs.3.1.bias разморожен
# classifier.0.convs.4.1.weight разморожен
# classifier.0.convs.4.2.weight разморожен
# classifier.0.convs.4.2.bias разморожен
# classifier.0.project.0.weight разморожен
# classifier.0.project.1.weight разморожен
# classifier.0.project.1.bias разморожен
# classifier.1.weight разморожен
# classifier.2.weight разморожен
# classifier.2.bias разморожен
# classifier.4.weight разморожен
# classifier.4.bias разморожен
# aux_classifier.0.weight разморожен
# aux_classifier.1.weight разморожен
# aux_classifier.1.bias разморожен
# aux_classifier.4.weight разморожен
# aux_classifier.4.bias разморожен
# Эпоха 1/10, Итерация 0/879, Потери: 0.792522668838501
# Эпоха 1/10, Итерация 10/879, Потери: 0.7506295659325339
# Эпоха 1/10, Итерация 20/879, Потери: 0.7099063793818156
# Эпоха 1/10, Итерация 30/879, Потери: 0.6713620981862468
# Эпоха 1/10, Итерация 40/879, Потери: 0.634996062371789
# Эпоха 1/10, Итерация 50/879, Потери: 0.6013083440415999
# Эпоха 1/10, Итерация 60/879, Потери: 0.5713675261520949
# Эпоха 1/10, Итерация 70/879, Потери: 0.5443114017097044
# Эпоха 1/10, Итерация 80/879, Потери: 0.5189258202358529
# Эпоха 1/10, Итерация 90/879, Потери: 0.4982204679604415
# Эпоха 1/10, Итерация 100/879, Потери: 0.47960975854703697
# Эпоха 1/10, Итерация 110/879, Потери: 0.4634995379963437
# Эпоха 1/10, Итерация 120/879, Потери: 0.44565262799420635
# Эпоха 1/10, Итерация 130/879, Потери: 0.43027688676619347
# Эпоха 1/10, Итерация 140/879, Потери: 0.4155116647693282
# Эпоха 1/10, Итерация 150/879, Потери: 0.4024139342718566
# Эпоха 1/10, Итерация 160/879, Потери: 0.39094680242286706
# Эпоха 1/10, Итерация 170/879, Потери: 0.38163373571390297
# Эпоха 1/10, Итерация 180/879, Потери: 0.37107317256664046
# Эпоха 1/10, Итерация 190/879, Потери: 0.3612936160171219
# Эпоха 1/10, Итерация 200/879, Потери: 0.35303554798833175
# Эпоха 1/10, Итерация 210/879, Потери: 0.3447447328064679
# Эпоха 1/10, Итерация 220/879, Потери: 0.3356926688309169
# Эпоха 1/10, Итерация 230/879, Потери: 0.3281014103329543
# Эпоха 1/10, Итерация 240/879, Потери: 0.3211318528998442
# Эпоха 1/10, Итерация 250/879, Потери: 0.3151978730442989
# Эпоха 1/10, Итерация 260/879, Потери: 0.3086976441501201
# Эпоха 1/10, Итерация 270/879, Потери: 0.3018939010386537
# Эпоха 1/10, Итерация 280/879, Потери: 0.29673203502473455
# Эпоха 1/10, Итерация 290/879, Потери: 0.2907381092559841
# Эпоха 1/10, Итерация 300/879, Потери: 0.28512875280308964
# Эпоха 1/10, Итерация 310/879, Потери: 0.2796803631151987
# Эпоха 1/10, Итерация 320/879, Потери: 0.2751492611901411
# Эпоха 1/10, Итерация 330/879, Потери: 0.2703864103537672
# Эпоха 1/10, Итерация 340/879, Потери: 0.2652908799585359
# Эпоха 1/10, Итерация 350/879, Потери: 0.26133629817653586
# Эпоха 1/10, Итерация 360/879, Потери: 0.25912302961557526
# Эпоха 1/10, Итерация 370/879, Потери: 0.2555512110941172
# Эпоха 1/10, Итерация 380/879, Потери: 0.25190695296005
# Эпоха 1/10, Итерация 390/879, Потери: 0.24938924819269143
# Эпоха 1/10, Итерация 400/879, Потери: 0.24619544694139772
# Эпоха 1/10, Итерация 410/879, Потери: 0.24339302689960984
# Эпоха 1/10, Итерация 420/879, Потери: 0.24051131211628257
# Эпоха 1/10, Итерация 430/879, Потери: 0.23744871506247056
# Эпоха 1/10, Итерация 440/879, Потери: 0.23457103506440208
# Эпоха 1/10, Итерация 450/879, Потери: 0.231392320567647
# Эпоха 1/10, Итерация 460/879, Потери: 0.2296802423765111
# Эпоха 1/10, Итерация 470/879, Потери: 0.22710235170118367
# Эпоха 1/10, Итерация 480/879, Потери: 0.2246799235176024
# Эпоха 1/10, Итерация 490/879, Потери: 0.22302172791265906
# Эпоха 1/10, Итерация 500/879, Потери: 0.22178087257101625
# Эпоха 1/10, Итерация 510/879, Потери: 0.2194853082168009
# Эпоха 1/10, Итерация 520/879, Потери: 0.21806947176922076
# Эпоха 1/10, Итерация 530/879, Потери: 0.21566306067921798
# Эпоха 1/10, Итерация 540/879, Потери: 0.21358876514925093
# Эпоха 1/10, Итерация 550/879, Потери: 0.21184529022680437
# Эпоха 1/10, Итерация 560/879, Потери: 0.2097214568147366
# Эпоха 1/10, Итерация 570/879, Потери: 0.2079165186896111
# Эпоха 1/10, Итерация 580/879, Потери: 0.20596755276115133
# Эпоха 1/10, Итерация 590/879, Потери: 0.20388334815574782
# Эпоха 1/10, Итерация 600/879, Потери: 0.20183912805357512
# Эпоха 1/10, Итерация 610/879, Потери: 0.19998907099086213
# Эпоха 1/10, Итерация 620/879, Потери: 0.19780864295416217
# Эпоха 1/10, Итерация 630/879, Потери: 0.19652868578544036
# Эпоха 1/10, Итерация 640/879, Потери: 0.1948646359906972
# Эпоха 1/10, Итерация 650/879, Потери: 0.19446967497250542
# Эпоха 1/10, Итерация 660/879, Потери: 0.19259410355741696
# Эпоха 1/10, Итерация 670/879, Потери: 0.19075980796110878
# Эпоха 1/10, Итерация 680/879, Потери: 0.19058779267684478
# Эпоха 1/10, Итерация 690/879, Потери: 0.1888063140267401
# Эпоха 1/10, Итерация 700/879, Потери: 0.18750807108057294
# Эпоха 1/10, Итерация 710/879, Потери: 0.18687916002151164
# Эпоха 1/10, Итерация 720/879, Потери: 0.1854423089069153
# Эпоха 1/10, Итерация 730/879, Потери: 0.18444112637596238
# Эпоха 1/10, Итерация 740/879, Потери: 0.18268981347219987
# Эпоха 1/10, Итерация 750/879, Потери: 0.1826634580212411
# Эпоха 1/10, Итерация 760/879, Потери: 0.18131242697365807
# Эпоха 1/10, Итерация 770/879, Потери: 0.18044717942790917
# Эпоха 1/10, Итерация 780/879, Потери: 0.17897365723048525
# Эпоха 1/10, Итерация 790/879, Потери: 0.17796689820123834
# Эпоха 1/10, Итерация 800/879, Потери: 0.1768529164568799
# Эпоха 1/10, Итерация 810/879, Потери: 0.1756687478866295
# Эпоха 1/10, Итерация 820/879, Потери: 0.17438970364621148
# Эпоха 1/10, Итерация 830/879, Потери: 0.17388547585983496
# Эпоха 1/10, Итерация 840/879, Потери: 0.17308475085347005
# Эпоха 1/10, Итерация 850/879, Потери: 0.1721632568982072
# Эпоха 1/10, Итерация 860/879, Потери: 0.17129556518199482
# Эпоха 1/10, Итерация 870/879, Потери: 0.17024305911711177
# Эпоха 1/10, Средние потери: 0.1696, Средний IoU: 0.5572
# Эпоха 2/10, Итерация 0/879, Потери: 0.10335524380207062
# Эпоха 2/10, Итерация 10/879, Потери: 0.0667340372773734
# Эпоха 2/10, Итерация 20/879, Потери: 0.07733437764857497
# Эпоха 2/10, Итерация 30/879, Потери: 0.07827854078383215
# Эпоха 2/10, Итерация 40/879, Потери: 0.07361918665105249
# Эпоха 2/10, Итерация 50/879, Потери: 0.07222057550269015
# Эпоха 2/10, Итерация 60/879, Потери: 0.0685905256904051
# Эпоха 2/10, Итерация 70/879, Потери: 0.06949110024831665
# Эпоха 2/10, Итерация 80/879, Потери: 0.07264105609997555
# Эпоха 2/10, Итерация 90/879, Потери: 0.07519227753464992
# Эпоха 2/10, Итерация 100/879, Потери: 0.07750604368082367
# Эпоха 2/10, Итерация 110/879, Потери: 0.076949657637391
# Эпоха 2/10, Итерация 120/879, Потери: 0.08022103929692063
# Эпоха 2/10, Итерация 130/879, Потери: 0.08218679375207151
# Эпоха 2/10, Итерация 140/879, Потери: 0.08560235346568391
# Эпоха 2/10, Итерация 150/879, Потери: 0.08341766546005445
# Эпоха 2/10, Итерация 160/879, Потери: 0.08287222431220623
# Эпоха 2/10, Итерация 170/879, Потери: 0.08216877211952767
# Эпоха 2/10, Итерация 180/879, Потери: 0.08035916406455455
# Эпоха 2/10, Итерация 190/879, Потери: 0.08106944097098724
# Эпоха 2/10, Итерация 200/879, Потери: 0.08199152727124852
# Эпоха 2/10, Итерация 210/879, Потери: 0.08104856330371722
# Эпоха 2/10, Итерация 220/879, Потери: 0.08216008934617987
# Эпоха 2/10, Итерация 230/879, Потери: 0.08442872173648763
# Эпоха 2/10, Итерация 240/879, Потери: 0.08395601918387587
# Эпоха 2/10, Итерация 250/879, Потери: 0.083858809611979
# Эпоха 2/10, Итерация 260/879, Потери: 0.08417875661917916
# Эпоха 2/10, Итерация 270/879, Потери: 0.08559521012406837
# Эпоха 2/10, Итерация 280/879, Потери: 0.087111168759759
# Эпоха 2/10, Итерация 290/879, Потери: 0.08921681191849033
# Эпоха 2/10, Итерация 300/879, Потери: 0.08864878496445988
# Эпоха 2/10, Итерация 310/879, Потери: 0.08820092827500925
# Эпоха 2/10, Итерация 320/879, Потери: 0.08916267844038868
# Эпоха 2/10, Итерация 330/879, Потери: 0.08987103537951802
# Эпоха 2/10, Итерация 340/879, Потери: 0.08955039043809748
# Эпоха 2/10, Итерация 350/879, Потери: 0.08875744495848645
# Эпоха 2/10, Итерация 360/879, Потери: 0.08773008923348133
# Эпоха 2/10, Итерация 370/879, Потери: 0.08769316972306154
# Эпоха 2/10, Итерация 380/879, Потери: 0.08777166345203173
# Эпоха 2/10, Итерация 390/879, Потери: 0.08901692593894193
# Эпоха 2/10, Итерация 400/879, Потери: 0.09038091004545105
# Эпоха 2/10, Итерация 410/879, Потери: 0.0913568962039086
# Эпоха 2/10, Итерация 420/879, Потери: 0.09121736606711305
# Эпоха 2/10, Итерация 430/879, Потери: 0.0908599151103928
# Эпоха 2/10, Итерация 440/879, Потери: 0.09107715206942996
# Эпоха 2/10, Итерация 450/879, Потери: 0.09085090176724805
# Эпоха 2/10, Итерация 460/879, Потери: 0.09156874652523668
# Эпоха 2/10, Итерация 470/879, Потери: 0.09220531217817161
# Эпоха 2/10, Итерация 480/879, Потери: 0.09143408896351182
# Эпоха 2/10, Итерация 490/879, Потери: 0.09194477213937371
# Эпоха 2/10, Итерация 500/879, Потери: 0.0920052921098328
# Эпоха 2/10, Итерация 510/879, Потери: 0.09137443494445366
# Эпоха 2/10, Итерация 520/879, Потери: 0.09093401475046223
# Эпоха 2/10, Итерация 530/879, Потери: 0.09075017050154184
# Эпоха 2/10, Итерация 540/879, Потери: 0.09059235180234072
# Эпоха 2/10, Итерация 550/879, Потери: 0.08974634084728852
# Эпоха 2/10, Итерация 560/879, Потери: 0.08983377358791503
# Эпоха 2/10, Итерация 570/879, Потери: 0.09021452210856612
# Эпоха 2/10, Итерация 580/879, Потери: 0.09079094751130488
# Эпоха 2/10, Итерация 590/879, Потери: 0.09074409188176372
# Эпоха 2/10, Итерация 600/879, Потери: 0.09112504349801435
# Эпоха 2/10, Итерация 610/879, Потери: 0.09047143894770532
# Эпоха 2/10, Итерация 620/879, Потери: 0.09062323479908677
# Эпоха 2/10, Итерация 630/879, Потери: 0.09051373964190342
# Эпоха 2/10, Итерация 640/879, Потери: 0.09087413862527766
# Эпоха 2/10, Итерация 650/879, Потери: 0.090770645466234
# Эпоха 2/10, Итерация 660/879, Потери: 0.09067316921554652
# Эпоха 2/10, Итерация 670/879, Потери: 0.09041739525426118
# Эпоха 2/10, Итерация 680/879, Потери: 0.09019093425525967
# Эпоха 2/10, Итерация 690/879, Потери: 0.09016301910704279
# Эпоха 2/10, Итерация 700/879, Потери: 0.08999393779529356
# Эпоха 2/10, Итерация 710/879, Потери: 0.09041349917424923
# Эпоха 2/10, Итерация 720/879, Потери: 0.09011299645039932
# Эпоха 2/10, Итерация 730/879, Потери: 0.08975964526247066
# Эпоха 2/10, Итерация 740/879, Потери: 0.08932527950015949
# Эпоха 2/10, Итерация 750/879, Потери: 0.08907355010365638
# Эпоха 2/10, Итерация 760/879, Потери: 0.08966117611328696
# Эпоха 2/10, Итерация 770/879, Потери: 0.08951866446393898
# Эпоха 2/10, Итерация 780/879, Потери: 0.08926067379435641
# Эпоха 2/10, Итерация 790/879, Потери: 0.0891218525740199
# Эпоха 2/10, Итерация 800/879, Потери: 0.089329966414864
# Эпоха 2/10, Итерация 810/879, Потери: 0.08939578447320973
# Эпоха 2/10, Итерация 820/879, Потери: 0.08981672195484011
# Эпоха 2/10, Итерация 830/879, Потери: 0.08984283127661719
# Эпоха 2/10, Итерация 840/879, Потери: 0.0895585299853798
# Эпоха 2/10, Итерация 850/879, Потери: 0.08970831320911085
# Эпоха 2/10, Итерация 860/879, Потери: 0.09021742256308508
# Эпоха 2/10, Итерация 870/879, Потери: 0.09035534227008148
# Эпоха 2/10, Средние потери: 0.0899, Средний IoU: 0.5977
# Эпоха 3/10, Итерация 0/879, Потери: 0.13684873282909393
# Эпоха 3/10, Итерация 10/879, Потери: 0.10553627495061267
# Эпоха 3/10, Итерация 20/879, Потери: 0.09723009781113692
# Эпоха 3/10, Итерация 30/879, Потери: 0.07864399662902279
# Эпоха 3/10, Итерация 40/879, Потери: 0.07292338837755889
# Эпоха 3/10, Итерация 50/879, Потери: 0.07464617981995438
# Эпоха 3/10, Итерация 60/879, Потери: 0.07166544769386776
# Эпоха 3/10, Итерация 70/879, Потери: 0.07078752511928618
# Эпоха 3/10, Итерация 80/879, Потери: 0.07179428037991863
# Эпоха 3/10, Итерация 90/879, Потери: 0.06933757824475294
# Эпоха 3/10, Итерация 100/879, Потери: 0.06844779253374822
# Эпоха 3/10, Итерация 110/879, Потери: 0.071349676547421
# Эпоха 3/10, Итерация 120/879, Потери: 0.06988818264635634
# Эпоха 3/10, Итерация 130/879, Потери: 0.07547011176650306
# Эпоха 3/10, Итерация 140/879, Потери: 0.07639290261617367
# Эпоха 3/10, Итерация 150/879, Потери: 0.07671622680931889
# Эпоха 3/10, Итерация 160/879, Потери: 0.07517928995122636
# Эпоха 3/10, Итерация 170/879, Потери: 0.07662708806255233
# Эпоха 3/10, Итерация 180/879, Потери: 0.08014282139110795
# Эпоха 3/10, Итерация 190/879, Потери: 0.08049437978563352
# Эпоха 3/10, Итерация 200/879, Потери: 0.07978136369504442
# Эпоха 3/10, Итерация 210/879, Потери: 0.08083641138898817
# Эпоха 3/10, Итерация 220/879, Потери: 0.0809618516643932
# Эпоха 3/10, Итерация 230/879, Потери: 0.08098892366828082
# Эпоха 3/10, Итерация 240/879, Потери: 0.08034412501789474
# Эпоха 3/10, Итерация 250/879, Потери: 0.0796198274316897
# Эпоха 3/10, Итерация 260/879, Потери: 0.07958083965911947
# Эпоха 3/10, Итерация 270/879, Потери: 0.0821101182515001
# Эпоха 3/10, Итерация 280/879, Потери: 0.08310477086591445
# Эпоха 3/10, Итерация 290/879, Потери: 0.08228820005489379
# Эпоха 3/10, Итерация 300/879, Потери: 0.08061605515236969
# Эпоха 3/10, Итерация 310/879, Потери: 0.08118399469499324
# Эпоха 3/10, Итерация 320/879, Потери: 0.08274771853109293
# Эпоха 3/10, Итерация 330/879, Потери: 0.08260104094781094
# Эпоха 3/10, Итерация 340/879, Потери: 0.08240626964860123
# Эпоха 3/10, Итерация 350/879, Потери: 0.08359442130155713
# Эпоха 3/10, Итерация 360/879, Потери: 0.08269817729343833
# Эпоха 3/10, Итерация 370/879, Потери: 0.08315968315174799
# Эпоха 3/10, Итерация 380/879, Потери: 0.08289929490604896
# Эпоха 3/10, Итерация 390/879, Потери: 0.08337200210784632
# Эпоха 3/10, Итерация 400/879, Потери: 0.08361771748519672
# Эпоха 3/10, Итерация 410/879, Потери: 0.08354430879101411
# Эпоха 3/10, Итерация 420/879, Потери: 0.08286695219930305
# Эпоха 3/10, Итерация 430/879, Потери: 0.0821517091287676
# Эпоха 3/10, Итерация 440/879, Потери: 0.08243807884832831
# Эпоха 3/10, Итерация 450/879, Потери: 0.08217191523118585
# Эпоха 3/10, Итерация 460/879, Потери: 0.08246009865141354
# Эпоха 3/10, Итерация 470/879, Потери: 0.08174673908028253
# Эпоха 3/10, Итерация 480/879, Потери: 0.08184194073599924
# Эпоха 3/10, Итерация 490/879, Потери: 0.08219545408741945
# Эпоха 3/10, Итерация 500/879, Потери: 0.08206442973860902
# Эпоха 3/10, Итерация 510/879, Потери: 0.08132774737862225
# Эпоха 3/10, Итерация 520/879, Потери: 0.08085122576337343
# Эпоха 3/10, Итерация 530/879, Потери: 0.08186633624715237
# Эпоха 3/10, Итерация 540/879, Потери: 0.0825177969319777
# Эпоха 3/10, Итерация 550/879, Потери: 0.08235961704273216
# Эпоха 3/10, Итерация 560/879, Потери: 0.08241757801891622
# Эпоха 3/10, Итерация 570/879, Потери: 0.08202370247296376
# Эпоха 3/10, Итерация 580/879, Потери: 0.0826441150971347
# Эпоха 3/10, Итерация 590/879, Потери: 0.0829513197719055
# Эпоха 3/10, Итерация 600/879, Потери: 0.08256697803875199
# Эпоха 3/10, Итерация 610/879, Потери: 0.08262958192935674
# Эпоха 3/10, Итерация 620/879, Потери: 0.08245823264718896
# Эпоха 3/10, Итерация 630/879, Потери: 0.08251106001144473
# Эпоха 3/10, Итерация 640/879, Потери: 0.08292370254185498
# Эпоха 3/10, Итерация 650/879, Потери: 0.08317712143409751
# Эпоха 3/10, Итерация 660/879, Потери: 0.08259066301869981
# Эпоха 3/10, Итерация 670/879, Потери: 0.08205291175459763
# Эпоха 3/10, Итерация 680/879, Потери: 0.08182436584873828
# Эпоха 3/10, Итерация 690/879, Потери: 0.08139116589556813
# Эпоха 3/10, Итерация 700/879, Потери: 0.08117385767466694
# Эпоха 3/10, Итерация 710/879, Потери: 0.08204534841418455
# Эпоха 3/10, Итерация 720/879, Потери: 0.08214672754910075
# Эпоха 3/10, Итерация 730/879, Потери: 0.08189463667334573
# Эпоха 3/10, Итерация 740/879, Потери: 0.08178656202314896
# Эпоха 3/10, Итерация 750/879, Потери: 0.08119339059192573
# Эпоха 3/10, Итерация 760/879, Потери: 0.08098713168323667
# Эпоха 3/10, Итерация 770/879, Потери: 0.08050045068647553
# Эпоха 3/10, Итерация 780/879, Потери: 0.08001521481177203
# Эпоха 3/10, Итерация 790/879, Потери: 0.07976225995212587
# Эпоха 3/10, Итерация 800/879, Потери: 0.07987991239080268
# Эпоха 3/10, Итерация 810/879, Потери: 0.07945876496610876
# Эпоха 3/10, Итерация 820/879, Потери: 0.079735443798596
# Эпоха 3/10, Итерация 830/879, Потери: 0.07963846355315778
# Эпоха 3/10, Итерация 840/879, Потери: 0.07996112440062707
# Эпоха 3/10, Итерация 850/879, Потери: 0.0797814487164444
# Эпоха 3/10, Итерация 860/879, Потери: 0.07989395352872251
# Эпоха 3/10, Итерация 870/879, Потери: 0.0797560998446059
# Эпоха 3/10, Средние потери: 0.0801, Средний IoU: 0.6213
# Эпоха 4/10, Итерация 0/879, Потери: 0.007684017531573772
# Эпоха 4/10, Итерация 10/879, Потери: 0.07147905806248839
# Эпоха 4/10, Итерация 20/879, Потери: 0.0736100481202205
# Эпоха 4/10, Итерация 30/879, Потери: 0.07457997424588088
# Эпоха 4/10, Итерация 40/879, Потери: 0.08148403870078122
# Эпоха 4/10, Итерация 50/879, Потери: 0.08238375442577343
# Эпоха 4/10, Итерация 60/879, Потери: 0.08332830175879549
# Эпоха 4/10, Итерация 70/879, Потери: 0.08197791020477742
# Эпоха 4/10, Итерация 80/879, Потери: 0.07801741529486061
# Эпоха 4/10, Итерация 90/879, Потери: 0.07770828985619349
# Эпоха 4/10, Итерация 100/879, Потери: 0.07617350652039347
# Эпоха 4/10, Итерация 110/879, Потери: 0.07389534299203136
# Эпоха 4/10, Итерация 120/879, Потери: 0.07701387701263605
# Эпоха 4/10, Итерация 130/879, Потери: 0.07965495497812979
# Эпоха 4/10, Итерация 140/879, Потери: 0.07933653546299071
# Эпоха 4/10, Итерация 150/879, Потери: 0.08264767212040772
# Эпоха 4/10, Итерация 160/879, Потери: 0.08153410973200886
# Эпоха 4/10, Итерация 170/879, Потери: 0.081901162225557
# Эпоха 4/10, Итерация 180/879, Потери: 0.08097015637184046
# Эпоха 4/10, Итерация 190/879, Потери: 0.0815889180506243
# Эпоха 4/10, Итерация 200/879, Потери: 0.08081685381695924
# Эпоха 4/10, Итерация 210/879, Потери: 0.07896678543857065
# Эпоха 4/10, Итерация 220/879, Потери: 0.07911316854499989
# Эпоха 4/10, Итерация 230/879, Потери: 0.07857807463607488
# Эпоха 4/10, Итерация 240/879, Потери: 0.07705335184947212
# Эпоха 4/10, Итерация 250/879, Потери: 0.07602226195589777
# Эпоха 4/10, Итерация 260/879, Потери: 0.07725189639241131
# Эпоха 4/10, Итерация 270/879, Потери: 0.07738199202013907
# Эпоха 4/10, Итерация 280/879, Потери: 0.0778466823504197
# Эпоха 4/10, Итерация 290/879, Потери: 0.07732919049433262
# Эпоха 4/10, Итерация 300/879, Потери: 0.07767454762958559
# Эпоха 4/10, Итерация 310/879, Потери: 0.07905737663412593
# Эпоха 4/10, Итерация 320/879, Потери: 0.0798189480588815
# Эпоха 4/10, Итерация 330/879, Потери: 0.07992364128269368
# Эпоха 4/10, Итерация 340/879, Потери: 0.0794809598645026
# Эпоха 4/10, Итерация 350/879, Потери: 0.07862224238805282
# Эпоха 4/10, Итерация 360/879, Потери: 0.07827846810139118
# Эпоха 4/10, Итерация 370/879, Потери: 0.07978507977561408
# Эпоха 4/10, Итерация 380/879, Потери: 0.07992375486596363
# Эпоха 4/10, Итерация 390/879, Потери: 0.07996634691191451
# Эпоха 4/10, Итерация 400/879, Потери: 0.07976617775462623
# Эпоха 4/10, Итерация 410/879, Потери: 0.0789970612932912
# Эпоха 4/10, Итерация 420/879, Потери: 0.07819018937589826
# Эпоха 4/10, Итерация 430/879, Потери: 0.07746412578576921
# Эпоха 4/10, Итерация 440/879, Потери: 0.07757623579729002
# Эпоха 4/10, Итерация 450/879, Потери: 0.07699037193549908
# Эпоха 4/10, Итерация 460/879, Потери: 0.07658780728408222
# Эпоха 4/10, Итерация 470/879, Потери: 0.07663591320561186
# Эпоха 4/10, Итерация 480/879, Потери: 0.07603257149554743
# Эпоха 4/10, Итерация 490/879, Потери: 0.0756598772649898
# Эпоха 4/10, Итерация 500/879, Потери: 0.07639516388789236
# Эпоха 4/10, Итерация 510/879, Потери: 0.07603156472029576
# Эпоха 4/10, Итерация 520/879, Потери: 0.0760820294657075
# Эпоха 4/10, Итерация 530/879, Потери: 0.07573640045031148
# Эпоха 4/10, Итерация 540/879, Потери: 0.07594812864200134
# Эпоха 4/10, Итерация 550/879, Потери: 0.07638890143084981
# Эпоха 4/10, Итерация 560/879, Потери: 0.07620689106952405
# Эпоха 4/10, Итерация 570/879, Потери: 0.07594031330211098
# Эпоха 4/10, Итерация 580/879, Потери: 0.0760932927117675
# Эпоха 4/10, Итерация 590/879, Потери: 0.07609122705940542
# Эпоха 4/10, Итерация 600/879, Потери: 0.07629857270803284
# Эпоха 4/10, Итерация 610/879, Потери: 0.07640313844496778
# Эпоха 4/10, Итерация 620/879, Потери: 0.07643066448850884
# Эпоха 4/10, Итерация 630/879, Потери: 0.07677543802015636
# Эпоха 4/10, Итерация 640/879, Потери: 0.07689073535667473
# Эпоха 4/10, Итерация 650/879, Потери: 0.07715740857414112
# Эпоха 4/10, Итерация 660/879, Потери: 0.07744360234272778
# Эпоха 4/10, Итерация 670/879, Потери: 0.07720087785565262
# Эпоха 4/10, Итерация 680/879, Потери: 0.07708201237657435
# Эпоха 4/10, Итерация 690/879, Потери: 0.07655433461733173
# Эпоха 4/10, Итерация 700/879, Потери: 0.07612760490624927
# Эпоха 4/10, Итерация 710/879, Потери: 0.07628834891262688
# Эпоха 4/10, Итерация 720/879, Потери: 0.07685215251285185
# Эпоха 4/10, Итерация 730/879, Потери: 0.07694944736793657
# Эпоха 4/10, Итерация 740/879, Потери: 0.0769798025996619
# Эпоха 4/10, Итерация 750/879, Потери: 0.0770162566653025
# Эпоха 4/10, Итерация 760/879, Потери: 0.07719137571487728
# Эпоха 4/10, Итерация 770/879, Потери: 0.07738287505318064
# Эпоха 4/10, Итерация 780/879, Потери: 0.07761735867389338
# Эпоха 4/10, Итерация 790/879, Потери: 0.07757293609384207
# Эпоха 4/10, Итерация 800/879, Потери: 0.07783965343846642
# Эпоха 4/10, Итерация 810/879, Потери: 0.07756603841409179
# Эпоха 4/10, Итерация 820/879, Потери: 0.07759495694008764
# Эпоха 4/10, Итерация 830/879, Потери: 0.07729405902660083
# Эпоха 4/10, Итерация 840/879, Потери: 0.07710502699502565
# Эпоха 4/10, Итерация 850/879, Потери: 0.07655101827073287
# Эпоха 4/10, Итерация 860/879, Потери: 0.07655891126322449
# Эпоха 4/10, Итерация 870/879, Потери: 0.07632549763010252
# Эпоха 4/10, Средние потери: 0.0759, Средний IoU: 0.6346
# Эпоха 5/10, Итерация 0/879, Потери: 0.053666647523641586
# Эпоха 5/10, Итерация 10/879, Потери: 0.0542773354629224
# Эпоха 5/10, Итерация 20/879, Потери: 0.06167300249494258
# Эпоха 5/10, Итерация 30/879, Потери: 0.053812352024138935
# Эпоха 5/10, Итерация 40/879, Потери: 0.0627029792848611
# Эпоха 5/10, Итерация 50/879, Потери: 0.06343286397282545
# Эпоха 5/10, Итерация 60/879, Потери: 0.0694548483121163
# Эпоха 5/10, Итерация 70/879, Потери: 0.06824390317680655
# Эпоха 5/10, Итерация 80/879, Потери: 0.06634408051584974
# Эпоха 5/10, Итерация 90/879, Потери: 0.064168172504671
# Эпоха 5/10, Итерация 100/879, Потери: 0.0661717976701658
# Эпоха 5/10, Итерация 110/879, Потери: 0.06459075433143356
# Эпоха 5/10, Итерация 120/879, Потери: 0.06610798467458649
# Эпоха 5/10, Итерация 130/879, Потери: 0.06705586696114704
# Эпоха 5/10, Итерация 140/879, Потери: 0.07019350873240342
# Эпоха 5/10, Итерация 150/879, Потери: 0.0712834663738478
# Эпоха 5/10, Итерация 160/879, Потери: 0.07228066953859344
# Эпоха 5/10, Итерация 170/879, Потери: 0.07146651315780585
# Эпоха 5/10, Итерация 180/879, Потери: 0.06950250443956141
# Эпоха 5/10, Итерация 190/879, Потери: 0.07183917622077059
# Эпоха 5/10, Итерация 200/879, Потери: 0.07035541682230745
# Эпоха 5/10, Итерация 210/879, Потери: 0.06865472721500913
# Эпоха 5/10, Итерация 220/879, Потери: 0.06838858214826471
# Эпоха 5/10, Итерация 230/879, Потери: 0.06807713512960192
# Эпоха 5/10, Итерация 240/879, Потери: 0.06880062477299904
# Эпоха 5/10, Итерация 250/879, Потери: 0.06869113565500513
# Эпоха 5/10, Итерация 260/879, Потери: 0.06762382607029259
# Эпоха 5/10, Итерация 270/879, Потери: 0.06763354784248884
# Эпоха 5/10, Итерация 280/879, Потери: 0.06704523264483492
# Эпоха 5/10, Итерация 290/879, Потери: 0.0665439486069944
# Эпоха 5/10, Итерация 300/879, Потери: 0.06755596196102566
# Эпоха 5/10, Итерация 310/879, Потери: 0.0673089700614752
# Эпоха 5/10, Итерация 320/879, Потери: 0.06715465313754976
# Эпоха 5/10, Итерация 330/879, Потери: 0.06750687002907775
# Эпоха 5/10, Итерация 340/879, Потери: 0.06911777157563159
# Эпоха 5/10, Итерация 350/879, Потери: 0.06848631716768477
# Эпоха 5/10, Итерация 360/879, Потери: 0.06922423729603372
# Эпоха 5/10, Итерация 370/879, Потери: 0.06899488827080599
# Эпоха 5/10, Итерация 380/879, Потери: 0.06939459760096461
# Эпоха 5/10, Итерация 390/879, Потери: 0.06912498072544804
# Эпоха 5/10, Итерация 400/879, Потери: 0.0684243677621777
# Эпоха 5/10, Итерация 410/879, Потери: 0.06855243969303068
# Эпоха 5/10, Итерация 420/879, Потери: 0.06904419792557219
# Эпоха 5/10, Итерация 430/879, Потери: 0.06945008523989114
# Эпоха 5/10, Итерация 440/879, Потери: 0.07000121538307678
# Эпоха 5/10, Итерация 450/879, Потери: 0.07021981171340559
# Эпоха 5/10, Итерация 460/879, Потери: 0.06973877868720142
# Эпоха 5/10, Итерация 470/879, Потери: 0.07101068548777095
# Эпоха 5/10, Итерация 480/879, Потери: 0.07065899941437101
# Эпоха 5/10, Итерация 490/879, Потери: 0.07181567152110431
# Эпоха 5/10, Итерация 500/879, Потери: 0.07154363940261721
# Эпоха 5/10, Итерация 510/879, Потери: 0.07141600152315415
# Эпоха 5/10, Итерация 520/879, Потери: 0.07105049172339464
# Эпоха 5/10, Итерация 530/879, Потери: 0.07129648622439336
# Эпоха 5/10, Итерация 540/879, Потери: 0.07103268828892016
# Эпоха 5/10, Итерация 550/879, Потери: 0.07163541467003388
# Эпоха 5/10, Итерация 560/879, Потери: 0.07119088603802849
# Эпоха 5/10, Итерация 570/879, Потери: 0.07110551608874807
# Эпоха 5/10, Итерация 580/879, Потери: 0.07105927807503347
# Эпоха 5/10, Итерация 590/879, Потери: 0.07057214372195682
# Эпоха 5/10, Итерация 600/879, Потери: 0.06990381316808726
# Эпоха 5/10, Итерация 610/879, Потери: 0.0699582732905239
# Эпоха 5/10, Итерация 620/879, Потери: 0.06967634448576149
# Эпоха 5/10, Итерация 630/879, Потери: 0.07011652620702616
# Эпоха 5/10, Итерация 640/879, Потери: 0.06958152339198044
# Эпоха 5/10, Итерация 650/879, Потери: 0.06947738679480694
# Эпоха 5/10, Итерация 660/879, Потери: 0.06922985325072879
# Эпоха 5/10, Итерация 670/879, Потери: 0.06967940091276222
# Эпоха 5/10, Итерация 680/879, Потери: 0.06924215271500064
# Эпоха 5/10, Итерация 690/879, Потери: 0.0691597204097424
# Эпоха 5/10, Итерация 700/879, Потери: 0.06905028280455316
# Эпоха 5/10, Итерация 710/879, Потери: 0.06931708676874135
# Эпоха 5/10, Итерация 720/879, Потери: 0.06949654805129096
# Эпоха 5/10, Итерация 730/879, Потери: 0.06967616877767031
# Эпоха 5/10, Итерация 740/879, Потери: 0.06952069449023558
# Эпоха 5/10, Итерация 750/879, Потери: 0.06956222955417755
# Эпоха 5/10, Итерация 760/879, Потери: 0.0696668858969102
# Эпоха 5/10, Итерация 770/879, Потери: 0.06954714748827226
# Эпоха 5/10, Итерация 780/879, Потери: 0.06938310536328184
# Эпоха 5/10, Итерация 790/879, Потери: 0.06953674229744977
# Эпоха 5/10, Итерация 800/879, Потери: 0.06971478119629729
# Эпоха 5/10, Итерация 810/879, Потери: 0.06964867641177813
# Эпоха 5/10, Итерация 820/879, Потери: 0.07000972809390268
# Эпоха 5/10, Итерация 830/879, Потери: 0.06999749516721963
# Эпоха 5/10, Итерация 840/879, Потери: 0.07008512478845591
# Эпоха 5/10, Итерация 850/879, Потери: 0.06979949097586828
# Эпоха 5/10, Итерация 860/879, Потери: 0.06966032402002567
# Эпоха 5/10, Итерация 870/879, Потери: 0.069989877265646
# Эпоха 5/10, Средние потери: 0.0699, Средний IoU: 0.6450
# Эпоха 6/10, Итерация 0/879, Потери: 0.08789530396461487
# Эпоха 6/10, Итерация 10/879, Потери: 0.07622732052748854
# Эпоха 6/10, Итерация 20/879, Потери: 0.0702181016760213
# Эпоха 6/10, Итерация 30/879, Потери: 0.06621408808015046
# Эпоха 6/10, Итерация 40/879, Потери: 0.05949925941914865
# Эпоха 6/10, Итерация 50/879, Потери: 0.057839967415430675
# Эпоха 6/10, Итерация 60/879, Потери: 0.060980669608278595
# Эпоха 6/10, Итерация 70/879, Потери: 0.056604332536537676
# Эпоха 6/10, Итерация 80/879, Потери: 0.060077124611578055
# Эпоха 6/10, Итерация 90/879, Потери: 0.059798849114616005
# Эпоха 6/10, Итерация 100/879, Потери: 0.06179464206625108
# Эпоха 6/10, Итерация 110/879, Потери: 0.06046964066430322
# Эпоха 6/10, Итерация 120/879, Потери: 0.059858852431701484
# Эпоха 6/10, Итерация 130/879, Потери: 0.058730936484795264
# Эпоха 6/10, Итерация 140/879, Потери: 0.05845171886872738
# Эпоха 6/10, Итерация 150/879, Потери: 0.06011731324976446
# Эпоха 6/10, Итерация 160/879, Потери: 0.06022673147088437
# Эпоха 6/10, Итерация 170/879, Потери: 0.060887293677711694
# Эпоха 6/10, Итерация 180/879, Потери: 0.06072146460691786
# Эпоха 6/10, Итерация 190/879, Потери: 0.06119254055671901
# Эпоха 6/10, Итерация 200/879, Потери: 0.060672879156503656
# Эпоха 6/10, Итерация 210/879, Потери: 0.060135210672243374
# Эпоха 6/10, Итерация 220/879, Потери: 0.06045952180771334
# Эпоха 6/10, Итерация 230/879, Потери: 0.060866083939725056
# Эпоха 6/10, Итерация 240/879, Потери: 0.06169342533859165
# Эпоха 6/10, Итерация 250/879, Потери: 0.06232394322667612
# Эпоха 6/10, Итерация 260/879, Потери: 0.06252587866038084
# Эпоха 6/10, Итерация 270/879, Потери: 0.0618104980433724
# Эпоха 6/10, Итерация 280/879, Потери: 0.06089192503662216
# Эпоха 6/10, Итерация 290/879, Потери: 0.06191526700684935
# Эпоха 6/10, Итерация 300/879, Потери: 0.06189268904094557
# Эпоха 6/10, Итерация 310/879, Потери: 0.06210002904665025
# Эпоха 6/10, Итерация 320/879, Потери: 0.06113698755425758
# Эпоха 6/10, Итерация 330/879, Потери: 0.06255666753544481
# Эпоха 6/10, Итерация 340/879, Потери: 0.06173386786998826
# Эпоха 6/10, Итерация 350/879, Потери: 0.06262890184815559
# Эпоха 6/10, Итерация 360/879, Потери: 0.062395036845517005
# Эпоха 6/10, Итерация 370/879, Потери: 0.062036141232936326
# Эпоха 6/10, Итерация 380/879, Потери: 0.06298515085177374
# Эпоха 6/10, Итерация 390/879, Потери: 0.06352232163831534
# Эпоха 6/10, Итерация 400/879, Потери: 0.0637848870811329
# Эпоха 6/10, Итерация 410/879, Потери: 0.0637167250695627
# Эпоха 6/10, Итерация 420/879, Потери: 0.06403932914595759
# Эпоха 6/10, Итерация 430/879, Потери: 0.06443100448712931
# Эпоха 6/10, Итерация 440/879, Потери: 0.06396775808694292
# Эпоха 6/10, Итерация 450/879, Потери: 0.06430246405346844
# Эпоха 6/10, Итерация 460/879, Потери: 0.06473669560409985
# Эпоха 6/10, Итерация 470/879, Потери: 0.06581476902947099
# Эпоха 6/10, Итерация 480/879, Потери: 0.06647993045231702
# Эпоха 6/10, Итерация 490/879, Потери: 0.06686249946418565
# Эпоха 6/10, Итерация 500/879, Потери: 0.06679991389970535
# Эпоха 6/10, Итерация 510/879, Потери: 0.06616363252482127
# Эпоха 6/10, Итерация 520/879, Потери: 0.06635781593134558
# Эпоха 6/10, Итерация 530/879, Потери: 0.06570354328278571
# Эпоха 6/10, Итерация 540/879, Потери: 0.06594384250544397
# Эпоха 6/10, Итерация 550/879, Потери: 0.0662108097227963
# Эпоха 6/10, Итерация 560/879, Потери: 0.06621110985601743
# Эпоха 6/10, Итерация 570/879, Потери: 0.065972472261719
# Эпоха 6/10, Итерация 580/879, Потери: 0.0657899162039584
# Эпоха 6/10, Итерация 590/879, Потери: 0.0658732656816528
# Эпоха 6/10, Итерация 600/879, Потери: 0.06552465530747731
# Эпоха 6/10, Итерация 610/879, Потери: 0.06469778880879357
# Эпоха 6/10, Итерация 620/879, Потери: 0.06444467940921153
# Эпоха 6/10, Итерация 630/879, Потери: 0.0647085844620283
# Эпоха 6/10, Итерация 640/879, Потери: 0.06511044457217739
# Эпоха 6/10, Итерация 650/879, Потери: 0.06525866393130073
# Эпоха 6/10, Итерация 660/879, Потери: 0.06540029800606895
# Эпоха 6/10, Итерация 670/879, Потери: 0.06544383639440596
# Эпоха 6/10, Итерация 680/879, Потери: 0.06512380129843677
# Эпоха 6/10, Итерация 690/879, Потери: 0.06497228472421482
# Эпоха 6/10, Итерация 700/879, Потери: 0.06506328375730398
# Эпоха 6/10, Итерация 710/879, Потери: 0.06511206019642919
# Эпоха 6/10, Итерация 720/879, Потери: 0.065356557181747
# Эпоха 6/10, Итерация 730/879, Потери: 0.06543427939025402
# Эпоха 6/10, Итерация 740/879, Потери: 0.06562173811454255
# Эпоха 6/10, Итерация 750/879, Потери: 0.06582478396690633
# Эпоха 6/10, Итерация 760/879, Потери: 0.06563437701972097
# Эпоха 6/10, Итерация 770/879, Потери: 0.0654059714939984
# Эпоха 6/10, Итерация 780/879, Потери: 0.06606424804052478
# Эпоха 6/10, Итерация 790/879, Потери: 0.06583048588423795
# Эпоха 6/10, Итерация 800/879, Потери: 0.06583608087566745
# Эпоха 6/10, Итерация 810/879, Потери: 0.06584121475444644
# Эпоха 6/10, Итерация 820/879, Потери: 0.06601531537043795
# Эпоха 6/10, Итерация 830/879, Потери: 0.06592621559360672
# Эпоха 6/10, Итерация 840/879, Потери: 0.0659047308701559
# Эпоха 6/10, Итерация 850/879, Потери: 0.06610791404202436
# Эпоха 6/10, Итерация 860/879, Потери: 0.06596391836955222
# Эпоха 6/10, Итерация 870/879, Потери: 0.06653964569795894
# Эпоха 6/10, Средние потери: 0.0664, Средний IoU: 0.6502
# Эпоха 7/10, Итерация 0/879, Потери: 0.005258629098534584
# Эпоха 7/10, Итерация 10/879, Потери: 0.05951863578097387
# Эпоха 7/10, Итерация 20/879, Потери: 0.06410910444156755
# Эпоха 7/10, Итерация 30/879, Потери: 0.07587198845501389
# Эпоха 7/10, Итерация 40/879, Потери: 0.07222323590980434
# Эпоха 7/10, Итерация 50/879, Потери: 0.07114783752088745
# Эпоха 7/10, Итерация 60/879, Потери: 0.07219022998708438
# Эпоха 7/10, Итерация 70/879, Потери: 0.07204256322182401
# Эпоха 7/10, Итерация 80/879, Потери: 0.07342590615843181
# Эпоха 7/10, Итерация 90/879, Потери: 0.0738756041410942
# Эпоха 7/10, Итерация 100/879, Потери: 0.07271010244016231
# Эпоха 7/10, Итерация 110/879, Потери: 0.07177530603928005
# Эпоха 7/10, Итерация 120/879, Потери: 0.06709767581533241
# Эпоха 7/10, Итерация 130/879, Потери: 0.06404059432724221
# Эпоха 7/10, Итерация 140/879, Потери: 0.06179224407706568
# Эпоха 7/10, Итерация 150/879, Потери: 0.06346510881049225
# Эпоха 7/10, Итерация 160/879, Потери: 0.06156970914785883
# Эпоха 7/10, Итерация 170/879, Потери: 0.06278859519832686
# Эпоха 7/10, Итерация 180/879, Потери: 0.06273496298965849
# Эпоха 7/10, Итерация 190/879, Потери: 0.06239817359579815
# Эпоха 7/10, Итерация 200/879, Потери: 0.062267678676854205
# Эпоха 7/10, Итерация 210/879, Потери: 0.06061510512024888
# Эпоха 7/10, Итерация 220/879, Потери: 0.06031192361263398
# Эпоха 7/10, Итерация 230/879, Потери: 0.06024152394666365
# Эпоха 7/10, Итерация 240/879, Потери: 0.06174603731784954
# Эпоха 7/10, Итерация 250/879, Потери: 0.06162001340802151
# Эпоха 7/10, Итерация 260/879, Потери: 0.06122815635205171
# Эпоха 7/10, Итерация 270/879, Потери: 0.060338921370706435
# Эпоха 7/10, Итерация 280/879, Потери: 0.0588964783127529
# Эпоха 7/10, Итерация 290/879, Потери: 0.05833538086313588
# Эпоха 7/10, Итерация 300/879, Потери: 0.057924830002023336
# Эпоха 7/10, Итерация 310/879, Потери: 0.058628813050675334
# Эпоха 7/10, Итерация 320/879, Потери: 0.05752738441755514
# Эпоха 7/10, Итерация 330/879, Потери: 0.057750645691523286
# Эпоха 7/10, Итерация 340/879, Потери: 0.05746508565495102
# Эпоха 7/10, Итерация 350/879, Потери: 0.05800588013560503
# Эпоха 7/10, Итерация 360/879, Потери: 0.05864094780374917
# Эпоха 7/10, Итерация 370/879, Потери: 0.05964035188027399
# Эпоха 7/10, Итерация 380/879, Потери: 0.05970552628780434
# Эпоха 7/10, Итерация 390/879, Потери: 0.06055032875706844
# Эпоха 7/10, Итерация 400/879, Потери: 0.060380277751963536
# Эпоха 7/10, Итерация 410/879, Потери: 0.06047301876065242
# Эпоха 7/10, Итерация 420/879, Потери: 0.060471593806876264
# Эпоха 7/10, Итерация 430/879, Потери: 0.060641975204456
# Эпоха 7/10, Итерация 440/879, Потери: 0.06068946844861207
# Эпоха 7/10, Итерация 450/879, Потери: 0.060619871902068925
# Эпоха 7/10, Итерация 460/879, Потери: 0.06144427014701674
# Эпоха 7/10, Итерация 470/879, Потери: 0.06129159502049358
# Эпоха 7/10, Итерация 480/879, Потери: 0.06072451814979106
# Эпоха 7/10, Итерация 490/879, Потери: 0.060767651895248916
# Эпоха 7/10, Итерация 500/879, Потери: 0.060793985796027156
# Эпоха 7/10, Итерация 510/879, Потери: 0.06055383171741313
# Эпоха 7/10, Итерация 520/879, Потери: 0.06000704225510244
# Эпоха 7/10, Итерация 530/879, Потери: 0.06046175097488919
# Эпоха 7/10, Итерация 540/879, Потери: 0.060019656656010424
# Эпоха 7/10, Итерация 550/879, Потери: 0.05992805759148662
# Эпоха 7/10, Итерация 560/879, Потери: 0.0601949237055459
# Эпоха 7/10, Итерация 570/879, Потери: 0.06031102631033126
# Эпоха 7/10, Итерация 580/879, Потери: 0.06052538434788104
# Эпоха 7/10, Итерация 590/879, Потери: 0.06043983964299131
# Эпоха 7/10, Итерация 600/879, Потери: 0.0604023913778876
# Эпоха 7/10, Итерация 610/879, Потери: 0.06030748627105127
# Эпоха 7/10, Итерация 620/879, Потери: 0.06033599812026779
# Эпоха 7/10, Итерация 630/879, Потери: 0.05989655347876015
# Эпоха 7/10, Итерация 640/879, Потери: 0.05993740383045989
# Эпоха 7/10, Итерация 650/879, Потери: 0.060662075423330825
# Эпоха 7/10, Итерация 660/879, Потери: 0.06068913062291893
# Эпоха 7/10, Итерация 670/879, Потери: 0.06102002863758334
# Эпоха 7/10, Итерация 680/879, Потери: 0.06128981689000762
# Эпоха 7/10, Итерация 690/879, Потери: 0.061959166548790356
# Эпоха 7/10, Итерация 700/879, Потери: 0.06230915223146004
# Эпоха 7/10, Итерация 710/879, Потери: 0.062139901668540665
# Эпоха 7/10, Итерация 720/879, Потери: 0.06237885666540959
# Эпоха 7/10, Итерация 730/879, Потери: 0.0621476648343541
# Эпоха 7/10, Итерация 740/879, Потери: 0.06225373454306491
# Эпоха 7/10, Итерация 750/879, Потери: 0.061898301459089936
# Эпоха 7/10, Итерация 760/879, Потери: 0.061974495934486465
# Эпоха 7/10, Итерация 770/879, Потери: 0.06190700268272634
# Эпоха 7/10, Итерация 780/879, Потери: 0.06177520810801741
# Эпоха 7/10, Итерация 790/879, Потери: 0.06172084044747516
# Эпоха 7/10, Итерация 800/879, Потери: 0.061909852950565156
# Эпоха 7/10, Итерация 810/879, Потери: 0.06281645745486848
# Эпоха 7/10, Итерация 820/879, Потери: 0.06353671121525598
# Эпоха 7/10, Итерация 830/879, Потери: 0.0635606714829166
# Эпоха 7/10, Итерация 840/879, Потери: 0.06376085164220328
# Эпоха 7/10, Итерация 850/879, Потери: 0.06378629902316439
# Эпоха 7/10, Итерация 860/879, Потери: 0.06347610217732194
# Эпоха 7/10, Итерация 870/879, Потери: 0.06370569439511319
# Эпоха 7/10, Средние потери: 0.0639, Средний IoU: 0.6649
# Эпоха 8/10, Итерация 0/879, Потери: 0.021408000960946083
# Эпоха 8/10, Итерация 10/879, Потери: 0.08819209843535315
# Эпоха 8/10, Итерация 20/879, Потери: 0.09462787605644692
# Эпоха 8/10, Итерация 30/879, Потери: 0.07158143081582122
# Эпоха 8/10, Итерация 40/879, Потери: 0.06975346431136131
# Эпоха 8/10, Итерация 50/879, Потери: 0.0628683902277593
# Эпоха 8/10, Итерация 60/879, Потери: 0.06030613982469821
# Эпоха 8/10, Итерация 70/879, Потери: 0.06256245487881168
# Эпоха 8/10, Итерация 80/879, Потери: 0.060890028862581574
# Эпоха 8/10, Итерация 90/879, Потери: 0.057786818742138014
# Эпоха 8/10, Итерация 100/879, Потери: 0.05772832072902434
# Эпоха 8/10, Итерация 110/879, Потери: 0.06803867566558691
# Эпоха 8/10, Итерация 120/879, Потери: 0.07034073306694011
# Эпоха 8/10, Итерация 130/879, Потери: 0.07004293780205131
# Эпоха 8/10, Итерация 140/879, Потери: 0.07062441391989271
# Эпоха 8/10, Итерация 150/879, Потери: 0.07022866042984637
# Эпоха 8/10, Итерация 160/879, Потери: 0.06955559884764902
# Эпоха 8/10, Итерация 170/879, Потери: 0.06949513126164675
# Эпоха 8/10, Итерация 180/879, Потери: 0.0696671060415098
# Эпоха 8/10, Итерация 190/879, Потери: 0.0687488304031769
# Эпоха 8/10, Итерация 200/879, Потери: 0.0673873315122794
# Эпоха 8/10, Итерация 210/879, Потери: 0.06672066892497241
# Эпоха 8/10, Итерация 220/879, Потери: 0.06592423023184028
# Эпоха 8/10, Итерация 230/879, Потери: 0.06517057462083377
# Эпоха 8/10, Итерация 240/879, Потери: 0.06493381602608471
# Эпоха 8/10, Итерация 250/879, Потери: 0.06440151928677279
# Эпоха 8/10, Итерация 260/879, Потери: 0.06432028895402792
# Эпоха 8/10, Итерация 270/879, Потери: 0.06312844584561966
# Эпоха 8/10, Итерация 280/879, Потери: 0.06308161504434097
# Эпоха 8/10, Итерация 290/879, Потери: 0.06341975362238529
# Эпоха 8/10, Итерация 300/879, Потери: 0.06327250815287505
# Эпоха 8/10, Итерация 310/879, Потери: 0.06363097097802536
# Эпоха 8/10, Итерация 320/879, Потери: 0.06413507915894005
# Эпоха 8/10, Итерация 330/879, Потери: 0.06414354109455722
# Эпоха 8/10, Итерация 340/879, Потери: 0.06416998206722466
# Эпоха 8/10, Итерация 350/879, Потери: 0.06435360235992575
# Эпоха 8/10, Итерация 360/879, Потери: 0.06377397541445616
# Эпоха 8/10, Итерация 370/879, Потери: 0.06365092305593303
# Эпоха 8/10, Итерация 380/879, Потери: 0.06299899583083536
# Эпоха 8/10, Итерация 390/879, Потери: 0.06265556247002158
# Эпоха 8/10, Итерация 400/879, Потери: 0.0621546663014692
# Эпоха 8/10, Итерация 410/879, Потери: 0.061817262201896275
# Эпоха 8/10, Итерация 420/879, Потери: 0.06205620088049314
# Эпоха 8/10, Итерация 430/879, Потери: 0.06235220078233059
# Эпоха 8/10, Итерация 440/879, Потери: 0.061902942122995026
# Эпоха 8/10, Итерация 450/879, Потери: 0.06246510293399771
# Эпоха 8/10, Итерация 460/879, Потери: 0.06216790530211423
# Эпоха 8/10, Итерация 470/879, Потери: 0.06195862760896856
# Эпоха 8/10, Итерация 480/879, Потери: 0.06144607250782973
# Эпоха 8/10, Итерация 490/879, Потери: 0.06145189373679042
# Эпоха 8/10, Итерация 500/879, Потери: 0.06090729346962649
# Эпоха 8/10, Итерация 510/879, Потери: 0.06125224236769824
# Эпоха 8/10, Итерация 520/879, Потери: 0.06109492840078228
# Эпоха 8/10, Итерация 530/879, Потери: 0.061533606760493235
# Эпоха 8/10, Итерация 540/879, Потери: 0.061879836131092124
# Эпоха 8/10, Итерация 550/879, Потери: 0.062040754650320565
# Эпоха 8/10, Итерация 560/879, Потери: 0.06186438980616078
# Эпоха 8/10, Итерация 570/879, Потери: 0.0628740325064077
# Эпоха 8/10, Итерация 580/879, Потери: 0.06253336909729602
# Эпоха 8/10, Итерация 590/879, Потери: 0.06216839745533598
# Эпоха 8/10, Итерация 600/879, Потери: 0.06228169640440946
# Эпоха 8/10, Итерация 610/879, Потери: 0.06200396427435041
# Эпоха 8/10, Итерация 620/879, Потери: 0.06199646797953488
# Эпоха 8/10, Итерация 630/879, Потери: 0.06226561674752262
# Эпоха 8/10, Итерация 640/879, Потери: 0.06214147849537304
# Эпоха 8/10, Итерация 650/879, Потери: 0.062399882772442426
# Эпоха 8/10, Итерация 660/879, Потери: 0.06186846900152242
# Эпоха 8/10, Итерация 670/879, Потери: 0.0614015074934666
# Эпоха 8/10, Итерация 680/879, Потери: 0.06203010158884105
# Эпоха 8/10, Итерация 690/879, Потери: 0.06194207613799834
# Эпоха 8/10, Итерация 700/879, Потери: 0.061960065136191976
# Эпоха 8/10, Итерация 710/879, Потери: 0.06159380001851663
# Эпоха 8/10, Итерация 720/879, Потери: 0.06134381677988328
# Эпоха 8/10, Итерация 730/879, Потери: 0.061001434896259775
# Эпоха 8/10, Итерация 740/879, Потери: 0.06121777198839852
# Эпоха 8/10, Итерация 750/879, Потери: 0.06108530247029036
# Эпоха 8/10, Итерация 760/879, Потери: 0.06082500063899278
# Эпоха 8/10, Итерация 770/879, Потери: 0.060449372602103646
# Эпоха 8/10, Итерация 780/879, Потери: 0.06053259136842709
# Эпоха 8/10, Итерация 790/879, Потери: 0.06064805541541922
# Эпоха 8/10, Итерация 800/879, Потери: 0.06092867928966368
# Эпоха 8/10, Итерация 810/879, Потери: 0.06097949067797884
# Эпоха 8/10, Итерация 820/879, Потери: 0.060821904311065496
# Эпоха 8/10, Итерация 830/879, Потери: 0.060668083754503735
# Эпоха 8/10, Итерация 840/879, Потери: 0.06090395714407709
# Эпоха 8/10, Итерация 850/879, Потери: 0.06105307981245478
# Эпоха 8/10, Итерация 860/879, Потери: 0.06079399006986941
# Эпоха 8/10, Итерация 870/879, Потери: 0.06083763112385151
# Эпоха 8/10, Средние потери: 0.0608, Средний IoU: 0.6763
# Эпоха 9/10, Итерация 0/879, Потери: 0.1314529925584793
# Эпоха 9/10, Итерация 10/879, Потери: 0.07354044031605801
# Эпоха 9/10, Итерация 20/879, Потери: 0.07353487995541877
# Эпоха 9/10, Итерация 30/879, Потери: 0.05524588856966265
# Эпоха 9/10, Итерация 40/879, Потери: 0.0574576745275408
# Эпоха 9/10, Итерация 50/879, Потери: 0.05732635740994239
# Эпоха 9/10, Итерация 60/879, Потери: 0.05356814016847581
# Эпоха 9/10, Итерация 70/879, Потери: 0.054227426243145804
# Эпоха 9/10, Итерация 80/879, Потери: 0.05472956300874091
# Эпоха 9/10, Итерация 90/879, Потери: 0.05732436695873001
# Эпоха 9/10, Итерация 100/879, Потери: 0.05758796251807731
# Эпоха 9/10, Итерация 110/879, Потери: 0.056389668200223765
# Эпоха 9/10, Итерация 120/879, Потери: 0.05717964929024389
# Эпоха 9/10, Итерация 130/879, Потери: 0.05751094721410537
# Эпоха 9/10, Итерация 140/879, Потери: 0.059351538809128634
# Эпоха 9/10, Итерация 150/879, Потери: 0.05717026400580287
# Эпоха 9/10, Итерация 160/879, Потери: 0.05787248305053745
# Эпоха 9/10, Итерация 170/879, Потери: 0.057999009773685266
# Эпоха 9/10, Итерация 180/879, Потери: 0.05813461485208213
# Эпоха 9/10, Итерация 190/879, Потери: 0.05754948697962276
# Эпоха 9/10, Итерация 200/879, Потери: 0.05685682875968386
# Эпоха 9/10, Итерация 210/879, Потери: 0.057148591685329535
# Эпоха 9/10, Итерация 220/879, Потери: 0.05665558354920661
# Эпоха 9/10, Итерация 230/879, Потери: 0.05562618337632096
# Эпоха 9/10, Итерация 240/879, Потери: 0.05425447110459595
# Эпоха 9/10, Итерация 250/879, Потери: 0.054166074782847407
# Эпоха 9/10, Итерация 260/879, Потери: 0.053630880377223265
# Эпоха 9/10, Итерация 270/879, Потери: 0.05385962545586496
# Эпоха 9/10, Итерация 280/879, Потери: 0.053557377872040686
# Эпоха 9/10, Итерация 290/879, Потери: 0.053926630430099556
# Эпоха 9/10, Итерация 300/879, Потери: 0.054292855493452065
# Эпоха 9/10, Итерация 310/879, Потери: 0.054506753322030525
# Эпоха 9/10, Итерация 320/879, Потери: 0.054495490609444794
# Эпоха 9/10, Итерация 330/879, Потери: 0.053925793421359065
# Эпоха 9/10, Итерация 340/879, Потери: 0.05406600330161515
# Эпоха 9/10, Итерация 350/879, Потери: 0.053481866029141595
# Эпоха 9/10, Итерация 360/879, Потери: 0.05319715851216146
# Эпоха 9/10, Итерация 370/879, Потери: 0.05297209161196928
# Эпоха 9/10, Итерация 380/879, Потери: 0.052575781535335236
# Эпоха 9/10, Итерация 390/879, Потери: 0.05237099722288597
# Эпоха 9/10, Итерация 400/879, Потери: 0.05283143690658357
# Эпоха 9/10, Итерация 410/879, Потери: 0.05328539391631745
# Эпоха 9/10, Итерация 420/879, Потери: 0.053232936092072795
# Эпоха 9/10, Итерация 430/879, Потери: 0.05396701371823405
# Эпоха 9/10, Итерация 440/879, Потери: 0.05382034479552783
# Эпоха 9/10, Итерация 450/879, Потери: 0.05437768220632005
# Эпоха 9/10, Итерация 460/879, Потери: 0.05473927654797684
# Эпоха 9/10, Итерация 470/879, Потери: 0.0549511524179808
# Эпоха 9/10, Итерация 480/879, Потери: 0.054551633783778766
# Эпоха 9/10, Итерация 490/879, Потери: 0.05447119442189336
# Эпоха 9/10, Итерация 500/879, Потери: 0.054464328292610414
# Эпоха 9/10, Итерация 510/879, Потери: 0.05401246586346128
# Эпоха 9/10, Итерация 520/879, Потери: 0.05393299112237647
# Эпоха 9/10, Итерация 530/879, Потери: 0.054238127684396065
# Эпоха 9/10, Итерация 540/879, Потери: 0.054191091282950805
# Эпоха 9/10, Итерация 550/879, Потери: 0.05500489450440135
# Эпоха 9/10, Итерация 560/879, Потери: 0.05549398144713724
# Эпоха 9/10, Итерация 570/879, Потери: 0.05535754874012647
# Эпоха 9/10, Итерация 580/879, Потери: 0.05519114727901356
# Эпоха 9/10, Итерация 590/879, Потери: 0.05550886665954682
# Эпоха 9/10, Итерация 600/879, Потери: 0.05533293450286863
# Эпоха 9/10, Итерация 610/879, Потери: 0.05556293060879624
# Эпоха 9/10, Итерация 620/879, Потери: 0.05560718439017001
# Эпоха 9/10, Итерация 630/879, Потери: 0.05593373236857449
# Эпоха 9/10, Итерация 640/879, Потери: 0.056475969818936496
# Эпоха 9/10, Итерация 650/879, Потери: 0.0564731548582497
# Эпоха 9/10, Итерация 660/879, Потери: 0.05641005502812249
# Эпоха 9/10, Итерация 670/879, Потери: 0.05643691943615575
# Эпоха 9/10, Итерация 680/879, Потери: 0.05641326316148207
# Эпоха 9/10, Итерация 690/879, Потери: 0.056298820519221436
# Эпоха 9/10, Итерация 700/879, Потери: 0.05642761382192623
# Эпоха 9/10, Итерация 710/879, Потери: 0.05612893172611159
# Эпоха 9/10, Итерация 720/879, Потери: 0.05623825496219579
# Эпоха 9/10, Итерация 730/879, Потери: 0.05654744070871171
# Эпоха 9/10, Итерация 740/879, Потери: 0.05645839225261393
# Эпоха 9/10, Итерация 750/879, Потери: 0.0565477948313078
# Эпоха 9/10, Итерация 760/879, Потери: 0.05670570691468613
# Эпоха 9/10, Итерация 770/879, Потери: 0.057119466355626126
# Эпоха 9/10, Итерация 780/879, Потери: 0.05706959874094935
# Эпоха 9/10, Итерация 790/879, Потери: 0.05722123065062089
# Эпоха 9/10, Итерация 800/879, Потери: 0.057157432138408244
# Эпоха 9/10, Итерация 810/879, Потери: 0.05705900305856832
# Эпоха 9/10, Итерация 820/879, Потери: 0.05699345586315505
# Эпоха 9/10, Итерация 830/879, Потери: 0.0568839970899905
# Эпоха 9/10, Итерация 840/879, Потери: 0.056987912213877195
# Эпоха 9/10, Итерация 850/879, Потери: 0.05715229173194175
# Эпоха 9/10, Итерация 860/879, Потери: 0.05717035793454865
# Эпоха 9/10, Итерация 870/879, Потери: 0.05701030403788359
# Эпоха 9/10, Средние потери: 0.0569, Средний IoU: 0.6844
# Эпоха 10/10, Итерация 0/879, Потери: 0.0035781364422291517
# Эпоха 10/10, Итерация 10/879, Потери: 0.043063879034227946
# Эпоха 10/10, Итерация 20/879, Потери: 0.041541505815638674
# Эпоха 10/10, Итерация 30/879, Потери: 0.046862134041504994
# Эпоха 10/10, Итерация 40/879, Потери: 0.05335726225521506
# Эпоха 10/10, Итерация 50/879, Потери: 0.052376752102966696
# Эпоха 10/10, Итерация 60/879, Потери: 0.057128847046129284
# Эпоха 10/10, Итерация 70/879, Потери: 0.05608150664008629
# Эпоха 10/10, Итерация 80/879, Потери: 0.0551261038283737
# Эпоха 10/10, Итерация 90/879, Потери: 0.053887931697817706
# Эпоха 10/10, Итерация 100/879, Потери: 0.05191281508818029
# Эпоха 10/10, Итерация 110/879, Потери: 0.05222578043577488
# Эпоха 10/10, Итерация 120/879, Потери: 0.0500443987947627
# Эпоха 10/10, Итерация 130/879, Потери: 0.05099145724848695
# Эпоха 10/10, Итерация 140/879, Потери: 0.05132767037077351
# Эпоха 10/10, Итерация 150/879, Потери: 0.05066816752818135
# Эпоха 10/10, Итерация 160/879, Потери: 0.05124003118914928
# Эпоха 10/10, Итерация 170/879, Потери: 0.04995683332114094
# Эпоха 10/10, Итерация 180/879, Потери: 0.05037215849460561
# Эпоха 10/10, Итерация 190/879, Потери: 0.04979804948463558
# Эпоха 10/10, Итерация 200/879, Потери: 0.05118443327347762
# Эпоха 10/10, Итерация 210/879, Потери: 0.05097531928472283
# Эпоха 10/10, Итерация 220/879, Потери: 0.05240030631362945
# Эпоха 10/10, Итерация 230/879, Потери: 0.05177740098226179
# Эпоха 10/10, Итерация 240/879, Потери: 0.05201619811896119
# Эпоха 10/10, Итерация 250/879, Потери: 0.052741898522216946
# Эпоха 10/10, Итерация 260/879, Потери: 0.052523395346996814
# Эпоха 10/10, Итерация 270/879, Потери: 0.053059036753482336
# Эпоха 10/10, Итерация 280/879, Потери: 0.05270642279237144
# Эпоха 10/10, Итерация 290/879, Потери: 0.05376294435860423
# Эпоха 10/10, Итерация 300/879, Потери: 0.05377749441152104
# Эпоха 10/10, Итерация 310/879, Потери: 0.05534293054220479
# Эпоха 10/10, Итерация 320/879, Потери: 0.05556164169774719
# Эпоха 10/10, Итерация 330/879, Потери: 0.055798507636881454
# Эпоха 10/10, Итерация 340/879, Потери: 0.05573509176704852
# Эпоха 10/10, Итерация 350/879, Потери: 0.05569057920208052
# Эпоха 10/10, Итерация 360/879, Потери: 0.05579649825877745
# Эпоха 10/10, Итерация 370/879, Потери: 0.05561551787953879
# Эпоха 10/10, Итерация 380/879, Потери: 0.05600963704354616
# Эпоха 10/10, Итерация 390/879, Потери: 0.056040583886867126
# Эпоха 10/10, Итерация 400/879, Потери: 0.05555335047554359
# Эпоха 10/10, Итерация 410/879, Потери: 0.055072726232737276
# Эпоха 10/10, Итерация 420/879, Потери: 0.05493447148020439
# Эпоха 10/10, Итерация 430/879, Потери: 0.05483806063434576
# Эпоха 10/10, Итерация 440/879, Потери: 0.054902894904571974
# Эпоха 10/10, Итерация 450/879, Потери: 0.05580256693516889
# Эпоха 10/10, Итерация 460/879, Потери: 0.05580659557794021
# Эпоха 10/10, Итерация 470/879, Потери: 0.055469138247594675
# Эпоха 10/10, Итерация 480/879, Потери: 0.055838117932028516
# Эпоха 10/10, Итерация 490/879, Потери: 0.055551721975363816
# Эпоха 10/10, Итерация 500/879, Потери: 0.0553788428880068
# Эпоха 10/10, Итерация 510/879, Потери: 0.055713942521520565
# Эпоха 10/10, Итерация 520/879, Потери: 0.05575083628631574
# Эпоха 10/10, Итерация 530/879, Потери: 0.05567222710301145
# Эпоха 10/10, Итерация 540/879, Потери: 0.05526904238643152
# Эпоха 10/10, Итерация 550/879, Потери: 0.05524058702763951
# Эпоха 10/10, Итерация 560/879, Потери: 0.056657433680714395
# Эпоха 10/10, Итерация 570/879, Потери: 0.05706490432888827
# Эпоха 10/10, Итерация 580/879, Потери: 0.056494355922153704
# Эпоха 10/10, Итерация 590/879, Потери: 0.05670743410673714
# Эпоха 10/10, Итерация 600/879, Потери: 0.05672501021821421
# Эпоха 10/10, Итерация 610/879, Потери: 0.056680933250447374
# Эпоха 10/10, Итерация 620/879, Потери: 0.05667453012573525
# Эпоха 10/10, Итерация 630/879, Потери: 0.05631079984669796
# Эпоха 10/10, Итерация 640/879, Потери: 0.05634703317229591
# Эпоха 10/10, Итерация 650/879, Потери: 0.05625374822692442
# Эпоха 10/10, Итерация 660/879, Потери: 0.05629077883472148
# Эпоха 10/10, Итерация 670/879, Потери: 0.05604986691680541
# Эпоха 10/10, Итерация 680/879, Потери: 0.05600455465099861
# Эпоха 10/10, Итерация 690/879, Потери: 0.05583714547372651
# Эпоха 10/10, Итерация 700/879, Потери: 0.05563547526087317
# Эпоха 10/10, Итерация 710/879, Потери: 0.05532404723072571
# Эпоха 10/10, Итерация 720/879, Потери: 0.055329363070342474
# Эпоха 10/10, Итерация 730/879, Потери: 0.054962201798114944
# Эпоха 10/10, Итерация 740/879, Потери: 0.054539502074005014
# Эпоха 10/10, Итерация 750/879, Потери: 0.054506444585768164
# Эпоха 10/10, Итерация 760/879, Потери: 0.05452905275481698
# Эпоха 10/10, Итерация 770/879, Потери: 0.05492557879697698
# Эпоха 10/10, Итерация 780/879, Потери: 0.055131746887032027
# Эпоха 10/10, Итерация 790/879, Потери: 0.0550822943713788
# Эпоха 10/10, Итерация 800/879, Потери: 0.055211866382825145
# Эпоха 10/10, Итерация 810/879, Потери: 0.05501558199134723
# Эпоха 10/10, Итерация 820/879, Потери: 0.055143787178829715
# Эпоха 10/10, Итерация 830/879, Потери: 0.05508481851372942
# Эпоха 10/10, Итерация 840/879, Потери: 0.05516680569866092
# Эпоха 10/10, Итерация 850/879, Потери: 0.055203370700634635
# Эпоха 10/10, Итерация 860/879, Потери: 0.05515809919630771
# Эпоха 10/10, Итерация 870/879, Потери: 0.05512245739668492
# Эпоха 10/10, Средние потери: 0.0552, Средний IoU: 0.6894

# %%
test_dataset = PlantSegDataset(test_images_path, test_masks_path, img_size=512)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, num_workers=4, drop_last=True)

# %%
model.eval()

predictions = []

with torch.no_grad():
    for images, _ in test_loader:
        images = images.to(device)

        outputs = model(images)
        preds = outputs['out'].argmax(dim=1)

        predictions.extend(preds.cpu().numpy())

print(f"Получены предсказания для {len(predictions)} изображений.")
# Out:
# Получены предсказания для 276 изображений.

# %%
import random

def apply_mask(image, mask, color=(255, 0, 0), alpha=0.5):
    """Накладывает маску на изображение с прозрачностью."""
    colored_mask = np.zeros_like(image)
    for i in range(3):
        colored_mask[:, :, i] = mask * color[i]
    
    overlay = cv2.addWeighted(image, 1 - alpha, colored_mask, alpha, 0)
    return overlay

def visualize_predictions(test_loader, predictions, num_samples=10):
    samples = random.sample(range(len(predictions)), num_samples)
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 3))
    
    for i, idx in enumerate(samples):
        image, mask = test_loader.dataset[idx]
        image = image.cpu().numpy().transpose(1, 2, 0)  # (C, H, W) -> (H, W, C)
        mask = mask.cpu().numpy()
        pred_mask = predictions[idx]
        
        overlay_pred = apply_mask((image * 255).astype(np.uint8), pred_mask, color=(255, 255, 0), alpha=0.5)
        
        
        overlay_gt = apply_mask((image * 255).astype(np.uint8), mask, color=(100, 238, 100), alpha=0.5)
        
        axes[i, 0].imshow(image)
        axes[i, 0].set_title("Original Image")
        
        axes[i, 1].imshow(overlay_gt)
        axes[i, 1].set_title("Ground Truth Mask Overlay")
        
        axes[i, 2].imshow(overlay_pred)
        axes[i, 2].set_title("Predicted Mask Overlay")
        
        axes[i, 3].imshow(pred_mask, cmap='jet', alpha=0.7)
        axes[i, 3].set_title("Predicted Mask")
        
        for ax in axes[i]:
            ax.axis("off")
    
    plt.tight_layout()
    plt.show()


visualize_predictions(test_loader, predictions, num_samples=10)

# %%
def calculate_iou(preds, labels, num_classes):
    """
    Функция для расчета IoU для всех классов.
    """
    preds = preds.argmax(dim=1)  # Преобразуем [B, C, H, W] -> [B, H, W]
    
    iou_per_class = []
    for i in range(num_classes):
        intersection = ((preds == i) & (labels == i)).sum().item()
        union = ((preds == i) | (labels == i)).sum().item()
        iou = intersection / union if union != 0 else float('nan')
        iou_per_class.append(iou)
        
    return np.nanmean(iou_per_class)  # Усредняем IoU по всем классам

def calculate_accuracy(preds, labels):
    correct = (preds == labels).sum().item()
    total = labels.numel()
    return correct / total



test_ious = []
test_accuracies = []

with torch.no_grad():
    for images, masks in test_loader:
        images, masks = images.to(device), masks.to(device)
        
        outputs = model(images)
        output = outputs['out']
        preds = output.argmax(dim=1)
        
        iou_batch = calculate_iou(output, masks, num_classes=117)
        test_ious.append(iou_batch)

      
        acc = calculate_accuracy(preds, masks)
        test_accuracies.append(acc)


mean_iou = np.nanmean(test_ious)
mean_accuracy = np.mean(test_accuracies)

print(f"Средний IoU на тестовой выборке: {mean_iou:.4f}")
print(f"Средняя Accuracy на тестовой выборке: {mean_accuracy:.4f}")
# Out:
# Средний IoU на тестовой выборке: 0.6101
# Средняя Accuracy на тестовой выборке: 0.9014

# %%
def dice_score(preds, masks, num_classes):
    
    preds = preds.cpu().numpy()
    masks = masks.cpu().numpy()

    print(f"preds shape: {preds.shape}, masks shape: {masks.shape}")

    dice_per_class = np.zeros(num_classes)
    
    for i in range(num_classes):
        intersection = np.logical_and(preds == i, masks == i).sum()
        union = (preds == i).sum() + (masks == i).sum()

        if union > 0:
            dice_per_class[i] = (2 * intersection) / union
    
    mean_dice = np.mean(dice_per_class[dice_per_class > 0])
    return dice_per_class, mean_dice

# %%
print(f"preds shape: {preds.shape}, masks shape: {masks.shape}")
# Out:
# preds shape: torch.Size([4, 512, 512]), masks shape: torch.Size([4, 512, 512])

# %%
preds = model(images)['out'].argmax(dim=1)
batch_dice, mean_dice = dice_score(preds, masks, num_classes)
print(f"Средний Dice Score: {mean_dice:.4f}")
# Out:
# preds shape: (4, 512, 512), masks shape: (4, 512, 512)
# Средний Dice Score: 0.7879

# %%
from sklearn.metrics import precision_recall_curve, auc

def calculate_map(preds, masks, num_classes):
    ap_per_class = []

    preds = preds.cpu().numpy()
    masks = masks.cpu().numpy()

    for i in range(1, num_classes):  # Пропускаем фон (0)
        y_true = (masks == i).astype(np.uint8).flatten()
        y_pred = (preds == i).astype(np.uint8).flatten()

        if np.sum(y_true) == 0:
            continue

        precision, recall, _ = precision_recall_curve(y_true, y_pred)
        ap = auc(recall, precision)  # Площадь под PR-кривой
        ap_per_class.append(ap)

    return np.mean(ap_per_class) if ap_per_class else 0.0  # Усредняем по классам

preds = outputs['out'].argmax(dim=1)

mean_ap = calculate_map(preds, masks, num_classes=2)
print(f"Средний mAP: {mean_ap:.4f}")
# Out:
# Средний mAP: 0.6825
